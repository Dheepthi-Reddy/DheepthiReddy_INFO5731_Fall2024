# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheepthi-Reddy/DheepthiReddy_INFO5731_Fall2024/blob/main/Vangeti_Dheepthi_Assignment_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Tuesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# Your code here

# importing necessary libraries
import requests                   # 'requests' library imported to send HTTP requests to fetch web pages
from bs4 import BeautifulSoup     # 'BeautifulSoup' library imported to parse HTML content and extract data and extracting data from web pages
import pandas as pd               # 'pandas' library for data manipulation operatioins

# define a 'getReviews' function to fetch IMDb reviews
def getReviews(totalReviews=1000):

    # empty list to store the fetched reviews
    reviews = []
    start = 0

    # imdb url of the user reviews page
    url = f"https://www.imdb.com/title/tt6791350/reviews/_ajax?ref_=undefined&paginationKey="

    # initialized 'last_key' to handle pagination
    last_key = ""

    # while loop to run untill 1000 reviews are fetched
    while len(reviews) < totalReviews:

        # making the get request to the url with the pagination key
        response = requests.get(f"{url}{last_key}")

        if response.status_code != 200:
            break  # to break the loop if the request failed

        # to parse html content of the page using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        # here we search for the div tage with name 'text show-more__control'
        reviewDiv = soup.find_all("div", class_="text show-more__control")

        # to loop through each review
        for review in reviewDiv:
            # reviews are appended to the 'reviews' list after removing any unwanted whitespace
            reviews.append(review.get_text(strip=True))
            # the loop stops once we reach the desired number of reviews
            if len(reviews) >= totalReviews:
                break
        # IMDb uses a pagination key for loading more reviews
        paginationKey = soup.find("div", class_="load-more-data")
        # if more more reviews are found then we update our last_key
        if paginationKey:
            last_key = paginationKey["data-key"]
        else:
            # if not found we break the loop
            break

    # to ensure 1000 reviews are collected
    return reviews[:totalReviews]

# executing the defined function
imdb_reviews = getReviews(1000)

# saving the review to CSV file
df = pd.DataFrame(imdb_reviews, columns=["Reviews"])
df.to_csv("UserReviews.csv", index=False)

print("A total of", len(imdb_reviews), "reviews saved to UserReviews.csv file.")
# Out:
# A total of 1000 reviews saved to UserReviews.csv file.

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.


# importing necessary libraries
import pandas as pd       # 'pandas' library for data manipulation operatioins
import re                 # regular expressions library for string manipulation operations
import nltk               # Natural Language Toolkit for text processing and analysis
from nltk.corpus import stopwords                         # to remove commonly used words from the particular language
from nltk.stem import PorterStemmer, WordNetLemmatizer    # 'PorterStemmer' for reducing the words, 'WordNetLemmatizer' to convert words to its dictionary form
from nltk.tokenize import word_tokenize                   # 'word_tokenize' to split the text into individual words

# downloading NLTK data
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')

# reading the reviews file using pandas dataframe
df = pd.read_csv("UserReviews.csv")

# defined a function using regular expressions library to remove noise like special characters and punctuations
def removeNoise(review):
    return re.sub(r'[^\w\s]', '', str(review))

# defined a function using regular expressions to remove numbers
def removeNumbers(review):
    return re.sub(r'\d+', '', review)

# defined a function to convert text to lowercase
def lowercase(review):
    return review.lower()

# defined function to remove stopwords
def removeStopwords(review):

    # initializing a set that has common words in english language
    stopWords = set(stopwords.words('english'))
    # to split the input string to seperate words
    tokens = word_tokenize(review)
    # initialized an empty list to store non-stopwords
    filtered_words = []

    # for loop to iterate over each word in the tokens
    for word in tokens:
        # to check if the word is not a stopword
        if word not in stopWords:
            # adding non-stopword words to the list
            filtered_words.append(word)
    # joining all the filtered words to a single string
    return ' '.join(filtered_words)

# Function for stemming the words
def stemmingFunc(review):
    # created a PorterStemmer object
    stemmer = PorterStemmer()

    # to split the input string to seperate words
    tokens = word_tokenize(review)
    # initialized empty list to store stemmed words
    stemmed_words = []

    # for loop to iterate over each word in the tokens list
    for word in tokens:
        # to stem each word
        stemmed_word = stemmer.stem(word)
        # appending the stemmed word to the list
        stemmed_words.append(stemmed_word)

    # joining all the stemmed words into a single string
    return ' '.join(stemmed_words)

# defined function for lemmatization
def lemmatizationFunc(review):

    #  created WordNetLemmatizer object
    lemmatizer = WordNetLemmatizer()

    # to split the input string to seperate words
    tokens = word_tokenize(review)
    # initialized an empty list to store lemmatized words
    lemmatized_words = []

    # for loop to iterate over each word in the tokens list
    for word in tokens:
         # to lemmatize each word
        lemmatized_word = lemmatizer.lemmatize(word)

        # appending the lemmatized word to the list
        lemmatized_words.append(lemmatized_word)

    # joining all the lemmatized words into a single string
    return ' '.join(lemmatized_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# 1. Removing the Noise and displaying after noise removal
df['Clean_Review'] = df['Reviews'].apply(removeNoise)
print("\n1. After Removing Noise:\n")
df.head(10)
# Out:
# 1. After Removing Noise:
#                                              Reviews  \
# 0  Guardians of the Galaxy Volume 3 is chaotic, w...
# 1  Having sat through some phase 4 films that fai...
# 2  This. This is what I've wanted. Yeah some of t...
# 3  It all leads back to where we once started off...
# 4  Up to this point, there has been one trilogy i...
# 5  I'm not one to cry at movies often, but this o...
# 6  "There is no God. That's why I stepped in." I ...
# 7  So first of all, everything to do with Rocket ...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG, and enjoyed Vol. 2 a l...
#
#                                         Clean_Review
# 0  Guardians of the Galaxy Volume 3 is chaotic we...
# 1  Having sat through some phase 4 films that fai...
# 2  This This is what Ive wanted Yeah some of the ...
# 3  It all leads back to where we once started off...
# 4  Up to this point there has been one trilogy in...
# 5  Im not one to cry at movies often but this one...
# 6  There is no God Thats why I stepped in I have ...
# 7  So first of all everything to do with Rocket i...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG and enjoyed Vol 2 a lot...

# %%
# 2. Removing the numbers and displaying
df['Clean_Review'] = df['Clean_Review'].apply(removeNumbers)
print("\n2. After Removing Numbers:\n")
df.head(10)
# Out:
# 2. After Removing Numbers:
#                                              Reviews  \
# 0  Guardians of the Galaxy Volume 3 is chaotic, w...
# 1  Having sat through some phase 4 films that fai...
# 2  This. This is what I've wanted. Yeah some of t...
# 3  It all leads back to where we once started off...
# 4  Up to this point, there has been one trilogy i...
# 5  I'm not one to cry at movies often, but this o...
# 6  "There is no God. That's why I stepped in." I ...
# 7  So first of all, everything to do with Rocket ...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG, and enjoyed Vol. 2 a l...
#
#                                         Clean_Review
# 0  Guardians of the Galaxy Volume  is chaotic wei...
# 1  Having sat through some phase  films that fail...
# 2  This This is what Ive wanted Yeah some of the ...
# 3  It all leads back to where we once started off...
# 4  Up to this point there has been one trilogy in...
# 5  Im not one to cry at movies often but this one...
# 6  There is no God Thats why I stepped in I have ...
# 7  So first of all everything to do with Rocket i...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG and enjoyed Vol  a lot ...

# %%
# 3. Converting the list to Lowercase
df['Clean_Review'] = df['Clean_Review'].apply(lowercase)
print("\n3. After Converting to Lowercase:\n")
df.head(10)
# Out:
# 3. After Converting to Lowercase:
#                                              Reviews  \
# 0  Guardians of the Galaxy Volume 3 is chaotic, w...
# 1  Having sat through some phase 4 films that fai...
# 2  This. This is what I've wanted. Yeah some of t...
# 3  It all leads back to where we once started off...
# 4  Up to this point, there has been one trilogy i...
# 5  I'm not one to cry at movies often, but this o...
# 6  "There is no God. That's why I stepped in." I ...
# 7  So first of all, everything to do with Rocket ...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG, and enjoyed Vol. 2 a l...
#
#                                         Clean_Review
# 0  guardians of the galaxy volume  is chaotic wei...
# 1  having sat through some phase  films that fail...
# 2  this this is what ive wanted yeah some of the ...
# 3  it all leads back to where we once started off...
# 4  up to this point there has been one trilogy in...
# 5  im not one to cry at movies often but this one...
# 6  there is no god thats why i stepped in i have ...
# 7  so first of all everything to do with rocket i...
# 8  a near perfect end to an incredible marvel tri...
# 9  i loved the first gotg and enjoyed vol  a lot ...

# %%
# 4. Removing Stopwords
df['Clean_Review'] = df['Clean_Review'].apply(removeStopwords)
print("\n4. After Removing Stopwords:\n")
df.head(10)
# Out:
# 4. After Removing Stopwords:
#                                              Reviews  \
# 0  Guardians of the Galaxy Volume 3 is chaotic, w...
# 1  Having sat through some phase 4 films that fai...
# 2  This. This is what I've wanted. Yeah some of t...
# 3  It all leads back to where we once started off...
# 4  Up to this point, there has been one trilogy i...
# 5  I'm not one to cry at movies often, but this o...
# 6  "There is no God. That's why I stepped in." I ...
# 7  So first of all, everything to do with Rocket ...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG, and enjoyed Vol. 2 a l...
#
#                                         Clean_Review
# 0  guardians galaxy volume chaotic weird oftentim...
# 1  sat phase films failed inspire guardians feels...
# 2  ive wanted yeah jokes bit silly tone bit confu...
# 3  leads back started great trilogies indicated p...
# 4  point one trilogy mcu excellent start finish t...
# 5  im one cry movies often one broke four merely ...
# 6  god thats stepped admit one best lines ever sp...
# 7  first everything rocket movie absolutely incre...
# 8  near perfect end incredible marvel trilogyguar...
# 9  loved first gotg enjoyed vol lot original quir...

# %%
# 5. Apply Stemming
df['Clean_Review'] = df['Clean_Review'].apply(stemmingFunc)
print("\n5. After Stemming the text:\n")
df.head(10)
# Out:
# 5. After Stemming the text:
#                                              Reviews  \
# 0  Guardians of the Galaxy Volume 3 is chaotic, w...
# 1  Having sat through some phase 4 films that fai...
# 2  This. This is what I've wanted. Yeah some of t...
# 3  It all leads back to where we once started off...
# 4  Up to this point, there has been one trilogy i...
# 5  I'm not one to cry at movies often, but this o...
# 6  "There is no God. That's why I stepped in." I ...
# 7  So first of all, everything to do with Rocket ...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG, and enjoyed Vol. 2 a l...
#
#                                         Clean_Review
# 0  guardian galaxi volum chaotic weird oftentim r...
# 1  sat phase film fail inspir guardian feel like ...
# 2  ive want yeah joke bit silli tone bit confus t...
# 3  lead back start great trilog indic past gotg s...
# 4  point one trilog mcu excel start finish time a...
# 5  im one cri movi often one broke four mere esti...
# 6  god that step admit one best line ever spoken ...
# 7  first everyth rocket movi absolut incred heart...
# 8  near perfect end incred marvel trilogyguardian...
# 9  love first gotg enjoy vol lot origin quirki fu...

# %%
# 6. Apply Lemmatization
df['Clean_Review'] = df['Clean_Review'].apply(lemmatizationFunc)
print("\n6. After Lemmatization:\n")
df.head(10)
# Out:
# 6. After Lemmatization:
#                                              Reviews  \
# 0  Guardians of the Galaxy Volume 3 is chaotic, w...
# 1  Having sat through some phase 4 films that fai...
# 2  This. This is what I've wanted. Yeah some of t...
# 3  It all leads back to where we once started off...
# 4  Up to this point, there has been one trilogy i...
# 5  I'm not one to cry at movies often, but this o...
# 6  "There is no God. That's why I stepped in." I ...
# 7  So first of all, everything to do with Rocket ...
# 8  A near perfect end to an incredible Marvel tri...
# 9  I loved the first GotG, and enjoyed Vol. 2 a l...
#
#                                         Clean_Review
# 0  guardian galaxi volum chaotic weird oftentim r...
# 1  sat phase film fail inspir guardian feel like ...
# 2  ive want yeah joke bit silli tone bit confus t...
# 3  lead back start great trilog indic past gotg s...
# 4  point one trilog mcu excel start finish time a...
# 5  im one cri movi often one broke four mere esti...
# 6  god that step admit one best line ever spoken ...
# 7  first everyth rocket movi absolut incred heart...
# 8  near perfect end incred marvel trilogyguardian...
# 9  love first gotg enjoy vol lot origin quirki fu...

# %%
# Save cleaned dataset
df.to_csv("UserReviews_Cleaned.csv", index = False)
print("\nCleaned data saved to UserReviews_Cleaned.csv file")
# Out:
# Cleaned data saved to UserReviews_Cleaned.csv file

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here

# 1. Parts of Speech (POS) Tagging:

# importing necessary library
import pandas as pd                           # 'pandas' library for data manipulation operatioins
import nltk                                   # Natural Language Toolkit for text processing and analysis
from nltk.tokenize import word_tokenize       # 'word_tokenize' to split the text into seperate words
from nltk import pos_tag                      # 'pos_tag' from nltk for parts of speech tagging
from collections import Counter               # to count items

# downloading necessary nltk data
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

# defined a function to perform POS tagging and counting
def POS_Tagging(reviews):
    # to split the input string to seperate words
    tokens = word_tokenize(reviews)
    # to perform POS tagging
    tags = pos_tag(tokens)
    # initializing counters for every speech of interest
    posCounts = Counter()
    # defined a dictionary for POS tags of interest
    posInterest = {'NN': 'Noun', 'VB': 'Verb', 'JJ': 'Adjective', 'RB': 'Adverb'}

    # to count occurrences of each POS of interest
    # word is the actual word from input text, tag is the POS assigned to that word
    for word, tag in tags:
        # for extracting first two charecters of POS tag
        if tag[:2] in posInterest:
            # count incrementing
            posCounts[posInterest[tag[:2]]] += 1
    return posCounts

# applying the POS tagging and counting function to each review and for collecting the results
list_POS_Counts = df['Clean_Review'].apply(POS_Tagging).tolist()
# initialied lists for every parts of speech
nouns = []
verbs = []
adjectives = []
adverbs = []
# loop to iterate through the list of counts and update separate lists for each part of speech.
for counts in list_POS_Counts:
    nouns.append(counts.get('Noun', 0))          # to get count of Nouns else 0 if not present
    verbs.append(counts.get('Verb', 0))          # to get count of Verbs else 0 if not present
    adjectives.append(counts.get('Adjective', 0))  # to get count of Adjectives else 0 if not present
    adverbs.append(counts.get('Adverb', 0))      # to get count of Adverbs else 0 if not present

# created a new DataFrame using the above lists
POS_df = pd.DataFrame({
    'Nouns': nouns,
    'Verbs': verbs,
    'Adjectives': adjectives,
    'Adverbs': adverbs,
})

# adding the Reviews column to the new DataFrame
POS_df.insert(0, 'Clean_Review', df['Clean_Review'].values)

# Display the new DataFrame
print("\n",POS_df.head())

# initialized total counts of each parts of speech
total_nouns = 0
total_verbs = 0
total_adjectives = 0
total_adverbs = 0

# loop to cumulate all the counts for each POS
for count in list_POS_Counts:
    total_nouns += count.get('Noun', 0)  # Noun counts
    total_verbs += count.get('Verb', 0)    # Verb counts
    total_adjectives += count.get('Adjective', 0)  # Adjective counts
    total_adverbs += count.get('Adverb', 0)  # Adverb counts

# printing the final counts
print(f"\nTotal Nouns: {total_nouns}")
print(f"Total Verbs: {total_verbs}")
print(f"Total Adjectives: {total_adjectives}")
print(f"Total Adverbs: {total_adverbs}")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                          Clean_Review  Nouns  Verbs  \
# 0  guardian galaxi volum chaotic weird oftentim r...     89     20
# 1  sat phase film fail inspir guardian feel like ...     58      8
# 2  ive want yeah joke bit silli tone bit confus t...     66     11
# 3  lead back start great trilog indic past gotg s...     36     12
# 4  point one trilog mcu excel start finish time a...     90     14
#
#    Adjectives  Adverbs
# 0          26        9
# 1          20        4
# 2          25        6
# 3          15        7
# 4          38        4
#
# Total Nouns: 62905
# Total Verbs: 15004
# Total Adjectives: 24950
# Total Adverbs: 5710

# %%
# 2. Constituency Parsing and Dependency Parsing:

# installing the spaCy library
# !pip install spacy
#downloading the English language model for spaCy
# !python -m spacy download en_core_web_sm
#installing the Benepar library, used for constituency parsing
# !pip install benepar
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting benepar
#   Downloading benepar-0.2.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.10/dist-packages (from benepar) (3.8.1)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.10/dist-packages (from benepar) (3.7.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from benepar) (2.4.1+cu121)
# Collecting torch-struct>=0.5 (from benepar)
#   Downloading torch_struct-0.5-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tokenizers>=0.9.4 in /usr/local/lib/python3.10/dist-packages (from benepar) (0.19.1)
# Requirement already satisfied: transformers>=4.2.2 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (4.44.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from benepar) (3.20.3)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from benepar) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2->benepar) (4.66.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy>=2.0.9->benepar) (1.26.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.9.4->benepar) (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->benepar) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (0.4.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (0.34.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[tokenizers,torch]>=4.2.2->benepar) (5.9.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy>=2.0.9->benepar) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->benepar) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (0.1.2)
# Downloading torch_struct-0.5-py3-none-any.whl (34 kB)
# Building wheels for collected packages: benepar
#   Building wheel for benepar (setup.py) ... done
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37626 sha256=d312684940ec3635be3c593396888374a44cf7884abcfc0856ed7f3a4b196c5e
#   Stored in directory: /root/.cache/pip/wheels/8d/4d/c1/a5af726368d5dbaaaa0b2dd36ed39b9da8cec46279a49bd6db
# Successfully built benepar
# Installing collected packages: torch-struct, benepar
# Successfully installed benepar-0.2.0 torch-struct-0.5

# %%
# Constituency Parsing:

import pandas as pd                     # 'pandas' library for data manipulation operatioins
import spacy                            # NLP library for text processing
import benepar    # a library for parsing for generating constituency parse trees
from nltk import Tree                   # importing tree class from NLTK for tree structuresera

# Download the Benepar model for generating constituency parse trees
benepar.download('benepar_en3')

userReviews_df = pd.read_csv("UserReviews_Cleaned.csv")    # loading the csv file
nlp = spacy.load("en_core_web_sm")        # to load the English language model from spaCy
# benepar component is added to spaCy pipeline, which does constituency parsing after standard parser process
nlp.add_pipe("benepar", config={"model": "benepar_en3"}, after='parser')

# defined a function to  split text to small chunks
def split_into_chunks(text, max_length=500):
    words = text.split()        # storing the list of words after splitting
    chunks = []                 # initializing an empty list to store chunks
    current_chunk = []          # initialized empty list to build the chunk of text for iteratingthrough the words.

    # for loop to iterate over each word in the list
    for word in words:
        current_chunk.append(word)    # each word is appended to the current chunk
        # Check if adding the next word would exceed the max_length
        if len(" ".join(current_chunk)) >= max_length:
            chunks.append(" ".join(current_chunk[:-1]))  # adding the current chunk without the last word
            current_chunk = [word]  # starting a new chunk with the last word

    # checking for any remaining words
    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks

print("\nConstituency Parsing:")

# for loop to  iterate through user reviews
for review in userReviews_df['Clean_Review'][:1]:

    chunks = split_into_chunks(review, max_length=500)  # splitting the review into smaller chunks with max limit of token size is 512
    # for loop to iterate through each chunks
    for chunk in chunks:
        try:
            doc = nlp(chunk)
            for sent in doc.sents:

                constituency_tree = sent._.parse_string    # Getting the constituency parse tree as a string
                tree = Tree.fromstring(constituency_tree)  # converting the string to tree representation
                tree.pretty_print()                        # Convert the string representation to an NLTK Tree object
        # exception handling for any errors
        except ValueError as e:
            print(f"Error processing chunk: {chunk}")
            print(e)
# Out:
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Unzipping models/benepar_en3.zip.
# /usr/local/lib/python3.10/dist-packages/benepar/parse_chart.py:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Constituency Parsing:
# /usr/local/lib/python3.10/dist-packages/torch/distributions/distribution.py:55: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(
#                                                                                                                                                                                                                                                                  S
#                           _______________________________________________________________________________________________________________________________________________________________________________________________________________________________________|__________________________________________
#                          |                            |                   |                                                                                                                                                                                                                                 VP
#                          |                            |                   |                   ______________________________________________________________________________________________________________________________________________________________________________________________________________|_____
#                          |                            |                   |                  |    |                                                                                                                                                                                                               NP
#                          |                            |                   |                  |    |                _______________________________________________________________________________________________________________________________________________________________________________________________|_________________________________________________________________________________________
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |                                                                                                                    VP
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |           _________________________________________________________________________________________________________|________
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |          |                                                                                                                  NP
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |          |    ______________________________________________________________________________________________________________|_______________
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |                                                                                     S
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |                                                                                     |
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |                                                                                     VP
#                          |                            |                   |                  |    |               |                                       |                                   |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |      _______________________________________________________________________________|______________
#                          |                            |                   |                  |    |               |                                      SBAR                                 |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |                                                                    VP
#                          |                            |                   |                  |    |               |                 ______________________|_____                              |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |     _______________________________________________________________|_____________________________
#                          |                            |                   |                  |    |               |                |                            S                             |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                |                     |    |   |        |                    VP
#                          |                            |                   |                  |    |               |                |         ___________________|____________                 |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                |                     |    |   |        |           _________|_________________
#                          |                            |                   |                  |    |               |                |        |       |     |                  S                |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                |                     |    |   |        |          |                          ADVP
#                          |                            |                   |                  |    |               |                |        |       |     |                  |                |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                |                     |    |   |        |          |          _________________|_____________________________________
#                          |                            |                   |                  |    |               |                |        |       |     |                  VP               |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                |                     |    |   |        |          |        ADVP                                                     |
#                          |                            |                   |                  |    |               |                |        |       |     |      ____________|___             |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                |                     |    |   |        |          |     ____|_________________                                      |
#                          |                            |                   NP                 |    |               |                |        |       |     |     |                VP           |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |                                NP                    |    |   |        |          |    |                      NP                                    |
#                          |                            |          _________|____________      |    |               |                |        |       |     |     |       _________|___         |    |     |     |     |     |      |     |    |         |         |                     |          |   |     |     |             |        |     |     |    |     |   |    |     |    |     ___________________________|_______________      |    |   |        |          |    |          ____________|______________________________       |
#                          NP                          ADVP       NP        |     |      |     |    |               NP              WHNP      |       |     |     |      |             NP       |    |     |     |     |     |      |     |    |         NP        |                     NP         |   |     |     NP            NP       |     |     |    NP    |   |    |     NP   |    |        ADJP               |    |    |     |     |    |   |        NP         |   ADVP       NP           |      |           |           |      |
#     _____________________|______________________      |     ____|____     |     |      |     |    |    ___________|__________      |        |       |     |     |      |          ___|___     |    |     |     |     |     |      |     |    |     ____|____     |          ___________|_____     |   |     |     |        _____|___     |     |     |    |     |   |    |     |    |    |     ____|________         |    |    |     |     |    |   |     ___|____      |    |     ____|____        |      |           |           |      |
#    JJ      FW     NN     JJ     JJ     JJ       NN    RB   JJ        NN   JJ    JJ    PRP    MD   VB JJS    NN    FW   JJ    NN   WDT       FW      RB    IN    NN     VB        RB      RB   JJ   JJ    NN    JJ    JJ    NN     RB    NN  VBN  PRP        JJ  VBD        ,           NN    NN  VBD  NN    VB    NN      JJ        CD  VBD    IN    VB   NN    RB  JJ   NN    NN  VBN   VB   JJ            JJ       JJ   NN   JJ    NN    FW   JJ  VB   CD       NN   VBD   RB   RB        NN      .      NN          JJ          NN     JJ
#    |       |      |      |      |      |        |     |    |         |    |     |      |     |    |   |     |     |    |     |     |        |       |     |     |      |         |       |    |    |     |     |     |     |      |     |    |    |         |    |         |           |     |    |   |     |     |       |         |    |     |     |    |     |   |    |     |    |    |    |             |        |    |    |     |     |    |   |    |        |     |    |    |         |       |      |           |           |      |
# guardian galaxi volum chaotic weird oftentim ridicul also full     heart emot great themesi must say best marvel movi sinc endgam that necessarili hard though need surpass     way     home amaz high moment lazi other marvel desper need hit theyv     final got ithighlightsever member crew got time shine rocket definit     one stood though see friend die wail pain grief made bawl high      evolutionari mock man heavi stuff proce rip face two     friend shot well thu      rocket traumat pastim revealedchukwudi iwuji fantast
#                                                                                                                                                                                                                                                                            i
#
#                                                                                                                                                                                             S
#             ________________________________________________________________________________________________________________________________________________________________________________|___________________________________________________________
#            |              |        |      |                   |                         |        |       |       |       |      |     |     |     |      |                         |                  |          |                                      VP
#            |              |        |      |                   |                         |        |       |       |       |      |     |     |     |      |                         |                  |          |               _______________________|___________________________________
#            |              |        |      |                   |                         |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |                           S
#            |              |        |      |                   |                         |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |                           |
#            |              |        |      |                   PP                        |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |                           VP
#            |              |        |      |      _____________|___                      |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |             ______________|_________
#            |              |        |      |     |                 NP                    |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |            |                        VP
#            |              |        |      |     |          _______|____                 |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |            |                    ____|_____________
#            |              |        |      |     |         |           SBAR              |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |            S                   |                  VP
#            |              |        |      |     |         |        ____|____            |        |       |       |       |      |     |     |     |      |                         |                  |          |              |   |     |       |     |   |   |            |                   |     _____________|___________________
#            |              |        |      |     |         |       |         S           |        |       |       |       |      |     |     |     |      |                         VP                 |          |              |   |     |       |     |   |   |            VP                  |    |                                 NP
#            |              |        |      |     |         |       |         |           |        |       |       |       |      |     |     |     |      |     ____________________|_____________     |          |              |   |     |       |     |   |   |     _______|_____              |    |                            _____|___________________________
#            |              |        |      |     |         |       |         VP          |        |       |       |       |      |     |     |     |      |    |         NP         |    |   |    |    |          |              |   |     |       |     |   |   |    |   |         VP            |    |                           |                        |        VP
#            |              |        |      |     |         |       |     ____|____       |        |       |       |       |      |     |     |     |      |    |     ____|____      |    |   |    |    |          |              |   |     |       |     |   |   |    |   |    _____|____         |    |                           |                        |     ___|____
#            NP             |        |      |     |         NP     WHNP  |         NP     |        |       |       NP      |      |     |     |     |      NP   |    NP        |    ADVP  |   |    VP   |          NP             |   NP    |       |     |   |   |    |   |   |          NP       |    |                           NP                      ADVP  |        NP
#     _______|______        |        |      |     |     ____|___    |    |         |      |        |       |       |       |      |     |     |     |      |    |    |         |     |    |   |    |    |      ____|______        |   |     |       |     |   |   |    |   |   |      ____|___     |    |      _____________________|___________________     |    |        |
#    NN      JJ     NN      RB       FW     FW    IN   NN       NN WDT  VBD        NN     NN       JJ      NN      NN     VBP     JJ    NN    NN    NN     NN  VBD  PRP        NN    RB   MD  RB   VB   VB    NN          FW      VB  NN    FW      VB    RB  RB  RB  VBD  RB  VB    JJ       NN   MD   VB    FW      FW      FW    FW    RB     NN     JJ   RB  VBD       NN
#    |       |      |       |        |      |     |    |        |   |    |         |      |        |       |       |       |      |     |     |     |      |    |    |         |     |    |   |    |    |     |           |       |   |     |       |     |   |   |    |   |   |     |        |    |    |     |       |       |     |     |      |      |    |    |        |
# villain certain point downright terrifi realli like line     god that took     place convinc villainth moment starlord scream agoni rocket live moment reson lost mani     peopl close  ca  nt stand lose anyon     elsegamora get lot charact develop  i   m  glad did  nt kiss quill     end would felt littl cheapdrax manti nebula adam warlock other also got     moment
#
#                                                                       S
#   ____________________________________________________________________|________________________________________________________
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |               VP
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |       ________|________
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |                 VP
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |     ____________|_____
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |                  NP
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |        __________|___________
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |       |                     ADJP
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |       |                 _____|____
# ADVP  |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |       NP               |         ADVP
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |    ___|____            |          |
#  RB   IN  FW    FW     RB    FW    FW       NN    FW    NN   RB  NN   JJ     JJ    NN     JJ      FW    FW     EX     MD   VB  JJ       NN          RB         RB
#  |    |   |     |      |     |     |        |     |     |    |   |    |      |     |      |       |     |      |      |    |   |        |           |          |
# well  i   m  surpris nobodi die honeston problem movi humor lot time good passabl time undercut realli emot scenesi could say lot     review     alreadi      long

# %% [markdown]
# **Constituency Parsing:**
#
# Constituency parsing is about the process of analyzing a text by breaking it down into hierarchical structures called constituents, showing that how words group together focusing on the grammatical relationships within a sentence to form a large unit.
#
#
# Example sentence: guardian galaxi volum chaotic weird
#
# In the above sentence the constituency tree groups words into different phrases, where:
#
# -> "guardian": this is a Noun (NN) and is the head noun of a noun phrase (NP).
#
# -> "galaxi": is also a Noun (NN) and it is a modifier to "gaurdian", like describing a specific type of guardian.
#
# -> "volum": this is a Noun(NN) and can be considered as a furthure modifier of "gaurdian".
#
# -> "chaotic": this is a adjective (JJ), describing the qualities of "gaurdian"
#
# -> "weird": this is another Adjective (JJ),  enhancing description of the nouns.
#
# The entire sentence I took here forms a Noun Phrase (NP) with "guardian" (NN) as the head, modified using additional nouns ("galaxi" and "volum") and adjectives ("chaotic" and "weird"). This entire text shows how these individual elements combine to explain the complex idea about the "guardian"

# %%
# Dependency Parsing:

from spacy import displacy  # NLP library for importing displacy for visualising dependencies

# for loop to iterate over dependency parsing for all cleaned reviews
for review in userReviews_df['Clean_Review'][:1]:

    doc = nlp(review)  # creating a doc object for processing the review text with spaCy
    print("Dependency Parsing:\n")
    displacy.render(doc, style='dep', jupyter=True)  # for rendering the dependency parse tree

    # for loop to iterate through each token in the processed document
    for token in doc:
        print(f"{token.text} -> {token.dep_} -> {token.pos_}")
# Out:
# Dependency Parsing:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="aa03748d9c9d42bc88b683f6faf68618-0" class="displacy" width="28050" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">guardian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">galaxi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">volum</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">chaotic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">weird</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">oftentim</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">ridicul</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">full</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">heart</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">emot</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">themesi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">must</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">say</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">best</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">marvel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">movi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">sinc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">endgam</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">necessarili</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">hard</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">though</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">surpass</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">home</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">amaz</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">high</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">moment</tspan>
#     <tspan class="displacy-tag" dy=
# guardian -> compound -> PROPN
# galaxi -> compound -> PROPN
# volum -> nmod -> PROPN
# chaotic -> amod -> ADJ
# weird -> amod -> PROPN
# oftentim -> compound -> PROPN
# ridicul -> nsubj -> PROPN
# also -> advmod -> ADV
# full -> amod -> ADJ
# heart -> compound -> NOUN
# emot -> nmod -> NOUN
# great -> amod -> ADJ
# themesi -> nsubj -> NOUN
# must -> aux -> AUX
# say -> ROOT -> VERB
# best -> amod -> ADJ
# marvel -> compound -> PROPN
# movi -> compound -> PROPN
# sinc -> compound -> PROPN
# endgam -> nsubj -> PROPN
# that -> det -> SCONJ
# necessarili -> nsubj -> NOUN
# hard -> advmod -> ADV
# though -> mark -> ADV
# need -> ccomp -> VERB
# surpass -> amod -> ADJ
# way -> npadvmod -> NOUN
# home -> advmod -> ADV
# amaz -> prep -> ADV
# high -> amod -> ADJ
# moment -> pobj -> NOUN
# lazi -> compound -> PROPN
# other -> amod -> ADJ
# marvel -> compound -> NOUN
# desper -> compound -> NOUN
# need -> nsubj -> NOUN
# hit -> ccomp -> VERB
# theyv -> compound -> PROPN
# final -> amod -> ADJ
# got -> compound -> VERB
# ithighlightseveri -> compound -> PROPN
# member -> compound -> NOUN
# crew -> nsubj -> NOUN
# got -> ccomp -> VERB
# time -> npadvmod -> NOUN
# shine -> ccomp -> NOUN
# rocket -> compound -> NOUN
# definit -> dobj -> NOUN
# one -> nsubj -> NUM
# stood -> ccomp -> VERB
# though -> mark -> ADV
# see -> advcl -> VERB
# friend -> compound -> NOUN
# die -> compound -> PROPN
# wail -> compound -> PROPN
# pain -> compound -> NOUN
# grief -> dobj -> NOUN
# made -> acl -> VERB
# bawl -> nsubj -> NOUN
# high -> amod -> ADJ
# evolutionari -> compound -> NOUN
# mock -> amod -> ADJ
# man -> compound -> NOUN
# heavi -> compound -> NOUN
# stuff -> compound -> NOUN
# proce -> compound -> NOUN
# rip -> nsubj -> NOUN
# face -> advcl -> VERB
# two -> nummod -> NUM
# friend -> dobj -> NOUN
# shot -> advcl -> VERB
# well -> advmod -> ADV
# thu -> amod -> ADJ
# rocket -> compound -> NOUN
# traumat -> nsubj -> NOUN
# pastim -> ccomp -> VERB
# revealedchukwudi -> compound -> PROPN
# iwuji -> compound -> PROPN
# fantast -> nsubj -> PROPN
# villain -> conj -> VERB
# certain -> amod -> ADJ
# point -> dobj -> NOUN
# downright -> npadvmod -> NOUN
# terrifi -> compound -> PROPN
# realli -> dobj -> PROPN
# like -> prep -> ADP
# line -> compound -> NOUN
# god -> pobj -> PROPN
# that -> nsubj -> PRON
# took -> relcl -> VERB
# place -> dobj -> NOUN
# convinc -> dobj -> PROPN
# villainth -> compound -> PROPN
# moment -> nmod -> PROPN
# starlord -> compound -> PROPN
# scream -> compound -> PROPN
# agoni -> compound -> PROPN
# rocket -> npadvmod -> NOUN
# live -> amod -> ADJ
# moment -> compound -> NOUN
# reson -> nsubj -> NOUN
# lost -> conj -> VERB
# mani -> compound -> PROPN
# peopl -> dobj -> NOUN
# close -> advmod -> ADV
# ca -> aux -> AUX
# nt -> neg -> PART
# stand -> advcl -> VERB
# lose -> advcl -> VERB
# anyon -> compound -> NOUN
# elsegamora -> dobj -> PROPN
# get -> compound -> VERB
# lot -> compound -> NOUN
# charact -> nsubj -> NOUN
# develop -> dep -> VERB
# i -> dobj -> PRON
# m -> ccomp -> VERB
# glad -> acomp -> ADJ
# did -> aux -> AUX
# nt -> neg -> PART
# kiss -> xcomp -> VERB
# quill -> compound -> NOUN
# end -> dobj -> NOUN
# would -> aux -> AUX
# felt -> ccomp -> VERB
# littl -> compound -> PROPN
# cheapdrax -> compound -> PROPN
# manti -> nsubj -> PROPN
# nebula -> compound -> PROPN
# adam -> appos -> PROPN
# warlock -> compound -> VERB
# other -> nsubj -> PROPN
# also -> advmod -> ADV
# got -> ccomp -> VERB
# moment -> dobj -> NOUN
# well -> intj -> INTJ
# i -> nsubj -> PRON
# m -> appos -> VERB
# surpris -> compound -> PROPN
# nobodi -> appos -> PROPN
# die -> compound -> PROPN
# honeston -> compound -> PROPN
# problem -> compound -> PROPN
# movi -> compound -> PROPN
# humor -> compound -> NOUN
# lot -> compound -> NOUN
# time -> npadvmod -> NOUN
# good -> amod -> ADJ
# passabl -> amod -> ADJ
# time -> npadvmod -> NOUN
# undercut -> amod -> PROPN
# realli -> compound -> PROPN
# emot -> compound -> PROPN
# scenesi -> nsubj -> NOUN
# could -> aux -> AUX
# say -> ROOT -> VERB
# lot -> compound -> NOUN
# review -> compound -> NOUN
# alreadi -> dobj -> NOUN
# long -> advmod -> ADV

# %% [markdown]
# **Dependency Parsing:**
#
# Dependency parsing checks for the grammatical structure of a sentence based on its dependency between the other words in a sentence.
#
# For the same sentence, the dependency parsing is:
#
# -> "guardian": this is the head noun (NN) of the phrase, acts as the central element.
#
# -> "galaxi": this word is linked as a compound modifier (compound) to "guardian" like a specific type of the guardian.
#
# -> "volum": this is linked as a nominal modifier (nmod) to "guardian" describing further about it.
#
# -> "chaotic": this is an adjectival modifier (amod), describing the qualities of "guardian" by enhancing its meaning.
#
# -> "weird": this word acts as an adjectival modifier (amod), further descsribing "guardian" and adding depth to its description.
#
# This dependency structure shows how "guardian" acts as the focal point, with "galaxi" and "volum" providing specific modifications to it, while "chaotic" and "weird" increase the overall characterization of the noun.

# %%
# 3. Named Entity Recognition

import spacy                      # NLP library for named entity recognition (NER)
from collections import Counter   # for counting hashable objects
import pandas as pd               # 'pandas' library for data manipulation operatioins

nlp = spacy.load("en_core_web_sm")    # Loading the spaCy model

def namedEntityRecognition(text):
    doc = nlp(text)   # processing the text using spaCy
    entities = []     # initializing a list to store the  entities
    for entity in doc.ents:    # for loop to extract entities and their labels
        entities.append((entity.text.strip(), entity.label_))  # Append the entity text and label as a tuple
    return entities

entity_list = df['Clean_Review'].apply(namedEntityRecognition)   # Apply NER to each review and calculating the results
allEntities = []     # initializing a list to store all the entities

# Iterate through each sublist of entities and extend the all_entities list
for sublist in entity_list:
    for entity in sublist:
        allEntities.append(entity)

entity_count = Counter(allEntities)     # counting each unique entity using Counter
entity_df = pd.DataFrame(entity_count.items(), columns=['Entity', 'Count'])    # converting the Counter to a DataFrame for formatting
# Split the Entity into two separate columns
entity_df[['Entity Text', 'Entity Type']] = pd.DataFrame(entity_df['Entity'].tolist(), index=entity_df.index)

# formatting the final dataframe properly
entity_df = entity_df.drop(columns=['Entity'])
entity_df = entity_df[['Entity Text', 'Entity Type', 'Count']]
entity_df = entity_df.sort_values(by='Count', ascending=False).reset_index(drop=True)   # Sort the DataFrame by Count in descending order

# final entity count dataframe
print(entity_df)
# Out:
#                       Entity Text Entity Type  Count
# 0                             one    CARDINAL    704
# 1                           first     ORDINAL    440
# 2                             two    CARDINAL    251
# 3                            seri        NORP    158
# 4                          second     ORDINAL    131
# ...                           ...         ...    ...
# 2562                    tensionth     ORDINAL      1
# 2563                   chang pace      PERSON      1
# 2564  filmmak motiv inspir vision      PERSON      1
# 2565                       soonwa         ORG      1
# 2566                        greek        NORP      1
#
# [2567 rows x 3 columns]

# %%
# Separate entities by type for counting
typesOfEntity = {}        # initialized empty dictionary to store different entity types as keys and their respective counts

# for loop to iterate through allEntities
for entity, labelName in allEntities:

  # checking if the labelName is already a key in typesOfEntity, if not it initializes a new Counter for that label.
    if labelName not in typesOfEntity:
        typesOfEntity[labelName] = Counter()
    typesOfEntity[labelName][entity] += 1

totalCount = {}     # initialized a empty dictionary to store total counts by entity type

# for loop to iterate over each entity type and its corresponding Counter of entities
for label, entities in typesOfEntity.items():
    totalCount[label] = sum(entities.values())  # counts of all entities under the specified label
    print(f"Entity Type: {label} => Total: {totalCount[label]}")
    for entity, count in entities.most_common():
        print(f"  {entity}: {count}")
# Out:
# Entity Type: CARDINAL => Total: 1167
#   one: 704
#   two: 251
#   three: 72
#   half: 37
#   ten: 15
#   four: 9
#   million: 7
#   togeth: 6
#   five: 6
#   everyon: 6
#   zero: 6
#   someth: 5
#   thousand: 3
#   famou: 3
#   billion: 3
#   one two: 3
#   six: 2
#   togeth one: 2
#   two three: 1
#   occas: 1
#   tear least five: 1
#   someth rewatch million: 1
#   nearli half: 1
#   dozen: 1
#   eleven: 1
#   ton: 1
#   twofold: 1
#   half dozen: 1
#   beauti: 1
#   someth beauti: 1
#   throughoutth: 1
#   balnk: 1
#   almost nine: 1
#   half billion: 1
#   howev: 1
#   nine: 1
#   showcas: 1
#   two film third: 1
#   one billion: 1
#   seven: 1
#   nico: 1
#   fightsom: 1
#   one million: 1
#   thisgunn: 1
#   waseven: 1
# Entity Type: ORG => Total: 1026
#   funni: 52
#   issu: 29
#   starlord: 27
#   abus: 27
#   chukwudi iwuji: 18
#   superhero movi: 16
#   plu: 15
#   guardian: 11
#   narr: 11
#   qualiti: 10
#   tissu: 9
#   genr: 8
#   gunn movi: 7
#   seri: 7
#   closur: 6
#   replac: 6
#   surpris movi: 6
#   confus: 5
#   funni time: 5
#   horrif: 5
#   primari: 4
#   legendari: 4
#   gunn guardian: 4
#   spectacl: 4
#   movi: 3
#   mei: 3
#   guardian movi: 3
#   everyth: 3
#   boundari: 3
#   movi movi: 3
#   qualiti movi: 3
#   klementieff: 3
#   invinc: 3
#   superhero: 3
#   gener: 3
#   counterearth: 3
#   armi: 3
#   significantli: 3
#   hilari: 3
#   littl hammi person relationship guardian: 2
#   confus movi: 2
#   necessari: 2
#   stakar: 2
#   gunn realli: 2
#   quill: 2
#   gunn manag: 2
#   funni one: 2
#   believ guardian: 2
#   tyler: 2
#   newcom: 2
#   favourit: 2
#   starlord chri pratt: 2
#   adventur guardian: 2
#   everyth movi: 2
#   sidelin: 2
#   gunn directori: 2
#   closur ragtag group: 2
#   someth movi: 2
#   best movi: 2
#   exactli: 2
#   realiti: 2
#   nova: 2
#   seri movi: 2
#   funni movi: 2
#   everi: 2
#   gunn suicid squad: 2
#   movi guardian: 2
#   cri movi: 2
#   movi funni: 2
#   starlord gamora: 2
#   gog: 2
#   whole movi: 2
#   el: 2
#   sonic: 2
#   gunn know: 2
#   gunn actor: 2
#   revealedchukwudi iwuji: 1
#   marvel movi movi: 1
#   superhero movi fashion: 1
#   first everyth rocket movi: 1
#   issu nd movi problem: 1
#   hugh jackman: 1
#   sidelin whole movi: 1
#   el realli cool cosmo: 1
#   starlord gomorra: 1
#   starlord drax gentl babygroot: 1
#   gunn deliv: 1
#   thrill hilari: 1
#   thrill movi: 1
#   kraglin respectivelyth movi: 1
#   daniela melchior: 1
#   henri braham dynam: 1
#   someth bear recognit: 1
#   mcu movi sinc: 1
#   gunn signatur: 1
#   unwieldi: 1
#   momentsand make mistak seriou movi darkest guardian movi: 1
#   gunn nibbl bit: 1
#   japan bless masterpiec bit: 1
#   closur mani charact: 1
#   movi favorit guardian movi went: 1
#   jame gunn movi: 1
#   min choreographi: 1
#   grotesqu: 1
#   loneli guardian half: 1
#   funni ultim: 1
#   stakar ogord timelin emphasi: 1
#   crusad: 1
#   deliv punchlin movi dark: 1
#   gunn resign marvel: 1
#   closelastli movi: 1
#   backstoryhilari: 1
#   funni high: 1
#   cri walk movi: 1
#   perfectli: 1
#   el film tv: 1
#   timerocket storylin best save: 1
#   averag marvel movi color: 1
#   durat movi: 1
#   nowher movi funni: 1
#   gillan debicki: 1
#   underwhelmingat: 1
#   run mill characterpet: 1
#   movieridicul: 1
#   squirrel: 1
#   funni thrill: 1
#   funni great: 1
#   adventur funni dog movi: 1
#   disney guardian: 1
#   stick: 1
#   coupl: 1
#   movi marvel movi: 1
#   sci: 1
#   honestli best marvel movi: 1
#   gunn ðÿ movi visual awesom stori emot: 1
#   realli hype watch movi: 1
#   wait commentari human fault: 1
#   chukwudi iwuji introduc: 1
#   gunn deliv masterpiec adam warlock: 1
#   gunn deliv movi color: 1
#   mcu movi movi: 1
#   buddi movi action movi comedi: 1
#   wella: 1
#   walt disney: 1
#   instantli rais: 1
#   honestli type movi marvel: 1
#   styleth melancholi: 1
#   spectacl truli: 1
#   heartwarm movi: 1
#   notabl: 1
#   spacedog possibl recal: 1
#   frustrat chang leaf whenev: 1
#   justifi continu: 1
#   misfir mean disappoint compar: 1
#   howev guardian beauti: 1
#   cri leav movi: 1
#   favourit movi: 1
#   homi hate ðÿðÿgo watch movi: 1
#   closur biggest fan: 1
#   spectacl cosmic landscap: 1
#   seri emerg: 1
#   hilari hundr: 1
#   goodby movi: 1
#   guinea pig countless instanc: 1
#   watch movi pleasur: 1
#   closur compon deserv: 1
#   starlord chri pratt nebula karen gillan: 1
#   gunn sculpt: 1
#   approach counterearth: 1
#   gunn calcul: 1
#   guid: 1
#   movi marvel sinc: 1
#   jame gunn fashionthi fit end guardian: 1
#   angri movi charact: 1
#   funni emot: 1
#   encor: 1
#   movi superhero: 1
#   world movi littl person: 1
#   gunn despit enjoy conclud: 1
#   hooo boythat: 1
#   noth el: 1
#   slightli clownish grim soul: 1
#   manchri pratt act: 1
#   gunn work movi: 1
#   social commentari: 1
#   seri strang: 1
#   funni dumba: 1
#   believ marvel: 1
#   reviv: 1
#   gunn fantast: 1
#   superhero movi one: 1
#   tentacl creatur: 1
#   gunn deliv movi: 1
#   aveng movi guardian: 1
#   big bang movi charact grown: 1
#   neglijabil: 1
#   spectacl witnessedon: 1
#   grey moment constantli: 1
#   movi sadli least favorit: 1
#   soldiersth movi: 1
#   sidelinedth: 1
#   inton: 1
#   terrif marvel movi funni: 1
#   primari coloursther scope depth: 1
#   katherin kennedi: 1
#   movi rate: 1
#   funni wall: 1
#   controlthi movi far: 1
#   gunn catapult: 1
#   scifi: 1
#   dark emot: 1
#   mcu movi guardian: 1
#   associ box scenario charact: 1
#   quill movi develop: 1
#   movi premis idea: 1
#   forc climax plotth climax: 1
#   expir animalsthi movi full frequent: 1
#   cyborg: 1
#   guardian chukwudi iwuji: 1
#   cri badpleas wait end: 1
#   movi studio ran movi director movi: 1
#   guardien movi: 1
#   entri guardian: 1
#   dark movi: 1
#   funni matur: 1
#   entireti movi: 1
#   inspir: 1
#   hamper truli: 1
#   gunn film enthusiast act honestli realli good across board: 1
#   volum wrap: 1
#   thrillingit: 1
#   experiencefirstli complain vfx: 1
#   funni dynam: 1
#   funnyi: 1
#   lucki watch day: 1
#   funni horriblegunn: 1
#   unforgettableid: 1
#   frustrat gamora: 1
#   simultan moron: 1
#   chukwudi iwuji unfortun: 1
#   el ail guardian: 1
#   materi movi: 1
#   friend guardian: 1
#   everi marvel movi movi: 1
#   besid function team: 1
#   guardian fleshi: 1
#   unexplor: 1
#   quickli movi: 1
#   happi movi exist: 1
#   control mcuth movi: 1
#   cheesi cring bad feel: 1
#   believ movi: 1
#   medicin marvel fan: 1
#   qualiti guardian: 1
#   thano: 1
#   catastroph: 1
#   inspir guardian movi: 1
#   gunn fantast job balanc: 1
#   movi heavi: 1
#   littl movi: 1
#   dread dog dinner movi: 1
#   gunn tell guardian stori exactli: 1
#   gunn direct guardian: 1
#   chase: 1
#   gunn dceu: 1
#   cooki: 1
#   movi entertain comed: 1
#   guardian introduc: 1
#   gunn clearli know make marvel movi heartfelt funni time: 1
#   customari: 1
#   gorgeou chemistri believ: 1
#   genr want decent stori: 1
#   frustrat: 1
#   mcu movi certainli: 1
#   maguir thwart: 1
#   fantast movi mani: 1
#   mayb wrap guardian: 1
#   nutti world destroy: 1
#   soonwa: 1
#   badli direct: 1
#   movi fill funni: 1
#   appli: 1
#   gunn slowli: 1
#   movi surpris: 1
#   everyth movi part: 1
#   closur movi: 1
#   compar movi latest: 1
#   favourit charact: 1
#   last houri: 1
#   gog movi nova corp guy: 1
#   issu movi: 1
#   uncanni guardian: 1
#   kodak: 1
#   gunn belov trilog: 1
#   narrativevisu guardian: 1
#   funni charm mei: 1
#   gunn comfort: 1
#   funni part: 1
#   ark point think: 1
#   cri movi steel: 1
#   entir: 1
#   wrap guardian: 1
#   animalssham disney control marvel movi: 1
#   membersth: 1
#   film truli: 1
#   ford: 1
#   honestli finest marvel movi: 1
#   movi buildup: 1
#   everi movi disney: 1
#   disney movi: 1
#   prick ayemanag: 1
#   believ fault: 1
#   quill forc confront: 1
#   movi premis: 1
#   conveni movi setup happi: 1
#   watch movi marvel: 1
#   falcon: 1
#   first guardian movi: 1
#   guardian wrap charact arc much impress feat let: 1
#   realli like movi sinc enjoy: 1
#   gunn movi intrigu: 1
#   gunn plansguardian probabl marvel movi: 1
#   everyth possibl funni mcu: 1
#   worri movi sinc: 1
#   showcas color movi: 1
#   seen mcu movi sinc: 1
#   adventur moviesi: 1
#   gunn deliv bittersweet: 1
#   stonesth: 1
#   bad movi marvel disney: 1
#   movi guardian movi: 1
#   myselfth: 1
#   hilari funni: 1
#   protagonist movi villian movi: 1
#   aveng movi marvel: 1
#   amazingth movi lot funni scene: 1
#   realiti marvel: 1
#   gunn guardian hard: 1
#   gunn direct movi: 1
#   supris emot depth movi: 1
#   villian movi: 1
#   unsalvag social skill frequent get laughth: 1
#   gunn know brian tallerico correctli: 1
#   nontonerel issu: 1
#   second movi guilti pleasur revisit: 1
#   funni awkward: 1
#   failur movi adam: 1
#   brilliantli kurt: 1
#   guardiansa quill: 1
#   funni welltim: 1
#   kevin: 1
#   adventur friend: 1
#   inspir chemistri: 1
#   cri movi sob: 1
#   issu charact: 1
#   junkthi movi derang: 1
#   gunn come sinc: 1
#   favorit movi year: 1
#   lightheart slightli goofi guardian: 1
#   favourit guardian movi: 1
#   abus puppi: 1
#   littl manipul: 1
#   scari movi: 1
#   genr scifi: 1
#   littl girl movi christwa: 1
#   funni charact: 1
#   guardian slightli graphic slightli adult perhapsi give direct jame gunn: 1
#   everi marvel movi: 1
#   simultan grip: 1
#   nec: 1
#   gunn doscreenplaystorylineplot develop: 1
#   entir roomlik: 1
#   guardiansa minut movi bit: 1
#   seri mani fan movi proof marvel: 1
#   movi compel: 1
#   setupwhil movi: 1
#   submerg fantast: 1
#   cud: 1
#   gunn star: 1
#   quickli: 1
#   funni waver: 1
#   uncanni: 1
#   believ conspiraci: 1
#   surviv vacuum: 1
#   honestli superhero: 1
#   gunn vision: 1
#   unfunni: 1
#   womansom: 1
#   funnyth act movi: 1
#   chikwudi iwuji: 1
#   unremark fayr: 1
#   cooper hangov: 1
#   saldana avatarthi movi: 1
#   movi cheesi: 1
#   funni compar previou marvel attempt: 1
#   realli truli: 1
#   firstli enjoy movi: 1
#   premis movi: 1
#   someth storylin: 1
#   careerth movi: 1
#   lucki achiev movi: 1
#   issu guardian: 1
#   someth everyth: 1
#   guardian movi worldbuild stori: 1
#   compani: 1
#   festth film roll one: 1
#   heroesth: 1
#   gunn direct: 1
#   wouldnb: 1
#   funni moment lot: 1
#   howev movi place: 1
#   min orgocorp sequenc: 1
#   gunn probabl: 1
#   darker underton larg: 1
#   welcom chang guardian flaw: 1
#   antman guardian hope: 1
#   marvel movi: 1
#   favourit supercrazi: 1
#   starlord technic geniu: 1
#   someon warn: 1
#   funni surpris: 1
#   decent movi: 1
#   movi lot issu: 1
#   gunn make u care talk raccoon: 1
#   showcas undeni geniu: 1
#   awesom: 1
#   cri marvel movi: 1
#   hotti: 1
#   rescu commerci: 1
#   wrap posse: 1
#   jame gunn save marvel phase: 1
#   hilari stun movi: 1
#   waay gener: 1
#   camaraderi ultracosm: 1
#   lightli: 1
#   gunn place chip: 1
#   exemplifi guardian galaxi: 1
#   invit: 1
#   cri hard movi: 1
#   everi charact: 1
#   cosmo: 1
#   watch movi wait long: 1
#   relat movi: 1
#   deedsa drawback movi credit: 1
#   curtainfal purpos movi provid: 1
#   childli curio contrast overwhelm prowess: 1
#   gunn guardian galaxi instantli: 1
#   counterearth constantli experi lower: 1
#   necessari earn: 1
#   gunn depart dceu hope: 1
#   watch movi: 1
#   warlord forc: 1
#   hundr movi: 1
#   marvel movi post: 1
#   gunn jame gunn: 1
#   movi exactli: 1
#   gunn strength charact movi: 1
#   saldana new nebula: 1
#   guardian movi chukwudi iwuji: 1
#   nostalg treat marvel fan: 1
#   challeng dilemma stori delv: 1
#   guardian movi one: 1
#   tragedi movi gotg: 1
#   david ayer: 1
#   quantumania worri movi: 1
#   leaddelv: 1
#   believ hype: 1
#   misfir leav fan yearn: 1
#   loki: 1
#   compar marvel movi: 1
#   hilari bromanc: 1
#   moron inconsist origin: 1
#   badli runtim long: 1
#   funni music: 1
#   chukwudi iwuji bow critic: 1
#   justifi: 1
#   moviesit littl darker: 1
#   el machin: 1
#   gunn dceu project suicid: 1
#   counterearth creat movi rocket: 1
#   howev movi: 1
#   separ movi gotg: 1
#   mayb movi: 1
#   gunn writer prepar: 1
#   movi marvel: 1
#   everi movi sinc: 1
#   believ star: 1
#   make movi blend: 1
#   american popul: 1
#   america produc movi: 1
#   moviego trust: 1
#   surviv: 1
#   vision guardian: 1
#   evryon movi: 1
#   lover moviego alik: 1
#   experi movi movi charact wellcraft distinct person: 1
#   el arc: 1
#   gunn mainli focus write: 1
#   denomin marvel movi: 1
#   thishonestli: 1
#   partin movi: 1
#   el everyth: 1
#   issu herean: 1
#   superhero movi superhero: 1
#   imbd: 1
#   strang movi alien: 1
#   expans: 1
#   gunn board: 1
#   surviv movi: 1
#   movi accompani: 1
#   funni mayb: 1
#   nostalg charm: 1
#   believ intens: 1
#   slightli darker: 1
#   inspir movi: 1
#   gunn continu: 1
#   appar place: 1
#   funni consid marvel movi funni: 1
#   funni dramat sad movi: 1
#   funni frequent: 1
#   gunn overindulg zani: 1
#   ball includ make: 1
#   seri timewa: 1
#   funni visual: 1
#   starlord pom klementieff awkward: 1
#   big plotlin: 1
#   wrap: 1
#   moron rambl: 1
#   love movi muchth: 1
#   filmsonc: 1
#   mph: 1
#   gunn deliv perfect goodby guardian third: 1
#   gunn blend emot: 1
#   time disney: 1
#   aveng wait disney recast: 1
#   best movi marvel: 1
#   funni exchang: 1
#   gambleth guardian movi chang idea marvel: 1
#   issu starlord chri pratt fallen drunken stupor: 1
#   gunn tri: 1
#   adrian belew mention: 1
#   adventur chri pratt act: 1
#   itgood news disney: 1
#   comicbook geek nitpick: 1
#   distinguish movi: 1
#   gunn continu deliv perfect: 1
#   gunn talent cast: 1
#   gunn deliv emot: 1
#   guardian greatli help nostalgiainduc: 1
#   everchang: 1
#   needledrop: 1
#   movi pale critic movi fan: 1
#   guardian favorit marvel movi combin: 1
#   funni despit: 1
#   bombast highoctan: 1
#   movi brilliantli: 1
#   issu infin: 1
#   aveng movi seri: 1
#   superhero movi busi: 1
#   believ convinc: 1
#   par ant: 1
#   suck movi: 1
#   onesa movi guardian: 1
#   funni guardian: 1
#   gunn last save: 1
#   bro movi guardian: 1
#   cool moviep: 1
#   commentin: 1
#   arc unlik movi genr: 1
#   villan calib: 1
#   quill guardian: 1
#   wellin movi: 1
#   gunn best movi: 1
#   gunn movi movi: 1
#   starlord seeeerious downgrad: 1
#   intrigu movi storylin: 1
#   movi blast mess emot: 1
#   gener wrap: 1
#   quippi marvel: 1
#   quippi: 1
#   honestli surpris movi: 1
#   sidelin movi howev: 1
#   movi postcreditscen peter: 1
#   movi bristl: 1
#   bay movi truli: 1
#   chukwudi iwujidesign: 1
#   guardian movi least group: 1
#   chukwudi experi bradley unfortun soul: 1
#   darker: 1
#   seri favorit marvel movi: 1
#   darker bittersweet: 1
#   guardiansth movi fair root charact: 1
#   funni seper movi: 1
#   fx movi make: 1
#   movi impress cool gradat emot: 1
#   cri immedi: 1
#   howev guardian galaxi movi: 1
#   slightli overstuf: 1
#   storylin guardian: 1
#   charm: 1
#   grimmer darker: 1
#   dynam guardian team: 1
#   hilari onelin bradley: 1
#   funni compar: 1
#   funni second: 1
#   best marvel movi: 1
#   qualiti marvel movi: 1
#   peter ugli: 1
#   centuri: 1
#   walt disney studio: 1
#   thrill marvel cosmic masterpieceguardian: 1
#   adventur movi dive deeper: 1
#   lover funni: 1
#   lastli love movi base: 1
#   contrari: 1
#   funni finer movi: 1
#   gunn ensur: 1
#   endgamenev desper featur critic audienc: 1
#   jordan eddi movi: 1
#   lover despit: 1
#   earnestli point bank: 1
#   funni entertain movi watch guardian: 1
#   danc: 1
#   surpris welcom: 1
#   mehit: 1
#   movi movi borderlin: 1
#   funni chang: 1
#   amaz movi seann gunn: 1
#   gunn craft extraordinari stori: 1
#   infus movi: 1
#   cri movi sinc frank frey funni: 1
#   gunn abl juggl: 1
#   seatth movi: 1
#   impactfulin: 1
#   guardian mustwatch movi: 1
#   movi arriv: 1
#   compani orgocorp embed travel orgocorp headquart: 1
#   guardian movi fantast: 1
#   compani orgocorp travel orgocorp headquart: 1
#   specul theel: 1
#   outsid guard: 1
#   quill groot board drax manti pursu quill group: 1
#   guardian arriv: 1
#   phylum kai: 1
#   christoph: 1
#   actionsuperhero movi: 1
#   abus movi: 1
#   shangchi loki werewolf night: 1
#   quantumania etern biggest: 1
#   favourit movi time: 1
#   greatli everyth movi: 1
#   rocketetcc everyth: 1
#   guardian soul movi movi chang: 1
#   antman movi: 1
#   gunn guardian galaxi movi: 1
#   dceu movi: 1
#   crazi movi latest: 1
#   hearti wait movi film reallythank: 1
#   gunn influenc movi: 1
#   substanc: 1
#   likesth plot movi load: 1
#   gunn cross: 1
#   earli movi actual: 1
#   masterpiec movi spectacular: 1
#   grootth movi insan absolut: 1
#   el background stori: 1
#   everyth possibl: 1
#   gunn edit movi realli: 1
#   funni movi reson emot: 1
#   decidedli darker movi last: 1
#   gunn evid: 1
#   worri possibl: 1
#   delv truli dark: 1
#   charm bizarr: 1
#   titular: 1
#   solac: 1
#   superhero movi plow sad: 1
#   believ youeveri singl: 1
#   vit flat movi: 1
#   henri braham: 1
#   gunn distinct: 1
#   guardian confront: 1
#   funni jame gunn: 1
#   challeng remain marvel command: 1
#   marvel movi guardian: 1
#   gunn given: 1
#   capitan: 1
# Entity Type: ORDINAL => Total: 720
#   first: 440
#   second: 131
#   third: 122
#   someth: 9
#   fourth: 6
#   fifth: 3
#   villainth: 2
#   occas: 1
#   tensionth: 1
#   meanth: 1
#   redemptionth: 1
#   offth: 1
#   selfth: 1
#   devotionth: 1
# Entity Type: PERSON => Total: 2040
#   gamora: 60
#   jame gunn: 43
#   chang: 34
#   peter quill: 31
#   narr: 30
#   unfortun: 15
#   everi: 14
#   klementieff: 13
#   everi singl: 12
#   extrem: 12
#   kraglin: 10
#   societi: 10
#   chukwudi iwuji: 10
#   everi movi: 9
#   dave bautista: 9
#   issu: 8
#   peter gamora: 8
#   mayb: 8
#   maria bakalova: 8
#   dave bautista drax: 8
#   relat: 7
#   gunn realli: 7
#   karen gillan: 6
#   john murphi: 6
#   peter: 6
#   terrif: 6
#   vin diesel: 6
#   fulli: 6
#   gore: 6
#   everi one: 6
#   goodby: 5
#   everi time: 5
#   zoe saldana: 5
#   silli: 5
#   gamora gamora: 5
#   gunn: 5
#   chri pratt: 5
#   everi scene: 5
#   god: 5
#   peter quill chri pratt: 5
#   mani: 5
#   qualiti: 5
#   kevin: 5
#   everi second: 5
#   chao: 5
#   materi: 4
#   reveng: 4
#   everi marvel: 4
#   gunn manag: 4
#   everi line: 4
#   new gamora: 4
#   loss gamora: 4
#   gamora nebula: 4
#   dr strang: 4
#   gamora quill: 4
#   karen gillan nebula: 4
#   everi charact: 4
#   gunn leav: 4
#   nebula: 4
#   everi frame: 4
#   everi moment: 4
#   bizarr: 4
#   starlord gamora: 4
#   honestli: 4
#   realiti: 4
#   stan lee: 4
#   quill gamora: 3
#   gamora saldana: 3
#   sean gunn: 3
#   everyth: 3
#   ralli: 3
#   nebula karen gillan: 3
#   howard duck: 3
#   christma: 3
#   everi guardian: 3
#   everi minut: 3
#   natur: 3
#   someon: 3
#   elizabeth debicki: 3
#   aveng: 3
#   rocket racoon: 3
#   john wick chapter: 3
#   greatli beauti person: 3
#   aveng movi: 2
#   realli enjoy: 2
#   michael rosenbaum: 2
#   compellingexclud: 2
#   chang everyth: 2
#   rocket chukwudi: 2
#   rocket peter: 2
#   realli funni: 2
#   profoundli: 2
#   angri gamora: 2
#   goodby guardian: 2
#   awar: 2
#   dave bautista manti pom: 2
#   dr moreau: 2
#   gamora zoe saldana: 2
#   gunn helm: 2
#   dedic: 2
#   gunn deliv: 2
#   horribl experi: 2
#   chang movi: 2
#   necessari: 2
#   dave bautista pom klementieff: 2
#   matur experi: 2
#   relat rocket: 2
#   messi: 2
#   gunn voic: 2
#   cooper vin diesel: 2
#   everi song: 2
#   juggl mani: 2
#   griev gamora: 2
#   el howev: 2
#   disneyhowev: 2
#   chao disappear: 2
#   nebula manti: 2
#   rocket storylin: 2
#   everi refer: 2
#   reson actionpack: 2
#   realli chang: 2
#   awesom: 2
#   millenni gener: 2
#   vin: 2
#   honestli cri: 2
#   dave bautista zoe: 2
#   inevit: 2
#   gunn chukwudi iwuji: 2
#   jim starlin: 2
#   scaveng: 2
#   nebula gamora: 2
#   gunn swan: 2
#   everi member: 2
#   bulli: 2
#   samuel l jackson: 2
#   jobjam gunn realli: 2
#   linda cardellini: 2
#   nebula forc: 2
#   groot vin diesel: 2
#   anyon elsegamora: 1
#   quill: 1
#   chang rule: 1
#   provid absolut: 1
#   beauti piec: 1
#   best quot: 1
#   mefrom: 1
#   jokingli hint: 1
#   nebula oddli: 1
#   howev unwarr: 1
#   zune: 1
#   angri shouti: 1
#   firstli adam: 1
#   kang depict quantumania: 1
#   qualiti one: 1
#   silli darker: 1
#   mostli obnoxi: 1
#   rocket gamora nebula: 1
#   vfx chang: 1
#   nitpick: 1
#   el someth: 1
#   everyon el: 1
#   strang hallow: 1
#   mostli quill: 1
#   everi battl: 1
#   silli genuin: 1
#   facsimil vari: 1
#   dr moreau lame: 1
#   debicki leader: 1
#   peter quill prattth action: 1
#   deliv heartfelt: 1
#   shine gamora nebula: 1
#   dave bautista deliv: 1
#   rocket maria bakalova: 1
#   fred raskin greg dauria: 1
#   creativ miracl brain dedic serv guardian gotg: 1
#   everi charact movi movi: 1
#   everi framei: 1
#   everi film: 1
#   screenwrit miracl: 1
#   phase mayb: 1
#   mayb gamora newcom: 1
#   miseri: 1
#   salvag movi: 1
#   honestli everi time: 1
#   decay societi: 1
#   everi mcu movi: 1
#   adam mummi boy: 1
#   manchild essenti: 1
#   kang anger: 1
#   gunn humour destroy: 1
#   everi ten: 1
#   everi scenenow: 1
#   antihero harden: 1
#   kidnap kevin: 1
#   storylin shouldv: 1
#   reviewit: 1
#   jame gunn one filmmak: 1
#   someon el: 1
#   storylin beauti intric: 1
#   kang scari show power importantli: 1
#   honestli everyth: 1
#   cameo hint hintit: 1
#   armageddon gg lolthank everyon help: 1
#   everi mistak: 1
#   movieon: 1
#   experi theori: 1
#   nebula nebula anatomi: 1
#   peter valu immedi: 1
#   peter guardian: 1
#   peter arc: 1
#   nerd: 1
#   substanc felt: 1
#   peter guardiansmeanwhil: 1
#   adam collectwith abil: 1
#   incompetenceth bigbad: 1
#   uneth experi: 1
#   recaptur: 1
#   decis gunn creativ: 1
#   aveng kang dynasti: 1
#   quill chri pratt: 1
#   gamora zoe: 1
#   gunn seri: 1
#   anim modifi: 1
#   unfortun explos: 1
#   portray gamora: 1
#   contrari darkveri: 1
#   gunn brilliantli: 1
#   gunn everyon masterpiec: 1
#   writingemot legit: 1
#   absolut beauti: 1
#   peter rocket: 1
#   neg gamora manta: 1
#   everyth simmer: 1
#   berri reimagin: 1
#   sidelin: 1
#   sinc disney: 1
#   greet lithuaniaguardian galaxi: 1
#   bautista pom klementieff: 1
#   sayjohn murphi: 1
#   innov: 1
#   max: 1
#   mm: 1
#   everi opportunityokay: 1
#   wrench gunn: 1
#   cartoon realiti: 1
#   issu howev: 1
#   unfortun matur: 1
#   gamora piec: 1
#   adam youv: 1
#   adrenalin: 1
#   awkwardli silli: 1
#   sometim slightli: 1
#   mayb problemi: 1
#   joketh movi: 1
#   sidelin one: 1
#   whoeverin summari: 1
#   gamora starlord: 1
#   kang ant: 1
#   slang minut chukwudi iwuji: 1
#   castl molli: 1
#   absolut magnific: 1
#   everi waysay: 1
#   bravo jame gunn: 1
#   scenographi realli: 1
#   peter quill play chri pratt funni: 1
#   sensit materi: 1
#   everyon sensit materi: 1
#   starlord gamora replac: 1
#   necessari humor: 1
#   awesom mani: 1
#   conveni confus: 1
#   new gamora parallel: 1
#   worstso everi marvel: 1
#   narr extrem: 1
#   plu music: 1
#   josef mengel yahweh experi: 1
#   mayb therel: 1
#   nebula laughingit: 1
#   noth truli: 1
#   miracul reviv: 1
#   cri wander: 1
#   chase gamora: 1
#   everyth perfectli: 1
#   wrongrat: 1
#   asham: 1
#   cri multipl time: 1
#   chang view otherwis: 1
#   manag balanc: 1
#   figur becam talk racoon: 1
#   everyth good pueril finicki: 1
#   sentiment aryan: 1
#   howev jame gunn: 1
#   moreth movi fan: 1
#   knew gamora: 1
#   aveng god: 1
#   cri god: 1
#   cooper gamora: 1
#   greenskin assassin cyborg: 1
#   buff golden assassin brutal attack: 1
#   gamora steal code biotech compani: 1
#   chukwudi lwuji: 1
#   peter pine loss: 1
#   soulmat gamora: 1
#   version gamora: 1
#   jimmi: 1
#   greatli: 1
#   flashi actionpack: 1
#   makeup prosthet: 1
#   kinda funni: 1
#   chang creat: 1
#   silli littl: 1
#   creativ qualiti: 1
#   declin qualiti sinc: 1
#   silli storylin: 1
#   masterpieceim: 1
#   jewel head: 1
#   gamora nebula peter: 1
#   instantli becam: 1
#   amazingwhen watch: 1
#   dave bautista vin: 1
#   remov star: 1
#   fairli enjoy movi: 1
#   qualiti everyth: 1
#   basi mani: 1
#   disguis fake selfright outrag: 1
#   gone downhil: 1
#   someon talk guardian: 1
#   veng: 1
#   includ gamora: 1
#   dedic second: 1
#   klementieff groot: 1
#   nebula karen gillan particip: 1
#   introduc happen groot vin diesel: 1
#   himselfalthough gunn: 1
#   festiv extrem: 1
#   dr moureau: 1
#   god mcu larg: 1
#   figur someon anyon: 1
#   dedic singl: 1
#   someon abil: 1
#   matur superhero: 1
#   dr frankenstein: 1
#   dave bautista remain: 1
#   destin divin: 1
#   jame gunn deliv: 1
#   gunn chang: 1
#   chang mayb gunn: 1
#   gunn awesom job: 1
#   strang everi marvel: 1
#   realli conveni circumstancesur: 1
#   generationif wan: 1
#   peter backstori: 1
#   everi film releas: 1
#   beauti heartbreakingwrenchingwarm: 1
#   gunn gunn: 1
#   amus fill brim marvel: 1
#   aveng massacr: 1
#   silli endur nd: 1
#   exchang tacki: 1
#   reminisc gamora: 1
#   experi innat: 1
#   jonathan major nevertheless: 1
#   youadam: 1
#   forc youi: 1
#   chang thr: 1
#   honestli wish: 1
#   arc conclus believ: 1
#   guid: 1
#   seri plu: 1
#   anyon guy fan: 1
#   extrem forc place: 1
#   horrifi extrem: 1
#   relat mcu: 1
#   juxtaposit horrif: 1
#   happi part: 1
#   gullibl cri: 1
#   inevit chang: 1
#   beauti relat: 1
#   peter quill drunken: 1
#   creativ adventur: 1
#   silli felt: 1
#   mani fiasco: 1
#   believ courtesi: 1
#   gunn someth futur: 1
#   absolut stinkerscooki: 1
#   sidelin much movi quill: 1
#   gunn brought: 1
#   aveng mani film tv: 1
#   indic polit: 1
#   worseit chang: 1
#   jerk smarta: 1
#   experi loo friend: 1
#   drama moviesso: 1
#   mayb jame: 1
#   prais sung alreadythi: 1
#   goodbyey nitpick realli: 1
#   everi speci: 1
#   dave batista: 1
#   breathtak felt: 1
#   lover: 1
#   thisadam: 1
#   goodby happi: 1
#   chang noth absolut: 1
#   tediou repetit: 1
#   extrem long base: 1
#   rememb awesom: 1
#   overstuf mixunfortun: 1
#   tellingit hour: 1
#   includ mostli: 1
#   necessari unnecessarili grim: 1
#   tragedi beauti moment: 1
#   dave bautista much: 1
#   admir perform: 1
#   coupl forc line: 1
#   happi guardian one: 1
#   everi minut tick: 1
#   mayb â½ hour cut: 1
#   tracksan ok watch: 1
#   everyth sinc endgam: 1
#   el revert back: 1
#   john favreau: 1
#   filmsunfortun: 1
#   congreg mcu fan: 1
#   geniu movi: 1
#   beauti everi: 1
#   strang antman: 1
#   realli kick: 1
#   dark knight: 1
#   rememb aveng: 1
#   gamora movi: 1
#   peter bad: 1
#   gamora rocket: 1
#   mildli amus: 1
#   sbecaus compani: 1
#   realli wish: 1
#   happi disney film era: 1
#   gamora dave bautista drax bradley: 1
#   rocket vin diesel groot: 1
#   spectacl extraordinari cinemat experi strap hold: 1
#   nostalg mani fan: 1
#   realli: 1
#   provid laughoutloud: 1
#   gunn knack blend: 1
#   highlight filmwhil: 1
#   heartchri pratt return: 1
#   saldana gamora dave bautista drax karen gillan nebula bradley cooper: 1
#   combin stun visual: 1
#   togeth howev: 1
#   narr complexityin: 1
#   tri outdo: 1
#   multipl timesth: 1
#   materi mani: 1
#   subtl chang: 1
#   everi scene accompani: 1
#   selv gotg: 1
#   strang gunn: 1
#   awesom quit possibl genesi declin: 1
#   peter accept gamora: 1
#   gunn masterpiec: 1
#   geniu gunn: 1
#   gunn beauti mind: 1
#   liter bawl: 1
#   realli geniusthey: 1
#   moreth neg: 1
#   someth jar plu: 1
#   honestli realiti: 1
#   chang climax: 1
#   kang quantumania: 1
#   relat rocket racoon: 1
#   realli surpris mani: 1
#   stan furri: 1
#   comic gamora: 1
#   remov repetit: 1
#   kevin come: 1
#   everi punch: 1
#   peter pratt rocket cooper: 1
#   nebula gillan: 1
#   manti klementieff: 1
#   bautista cosmo: 1
#   kraglin gunn: 1
#   mask gamora: 1
#   beauti proactiv: 1
#   wellkaren gillan gotten: 1
#   gunn manag wrap: 1
#   extrem worri guardian: 1
#   sprinkl gamora: 1
#   peter weirdli peter x nebula: 1
#   psychopathth vfx sfx: 1
#   realli gotten: 1
#   war gunn: 1
#   someth constantli: 1
#   repeatedli explicitli: 1
#   exercis extrem: 1
#   qualiti initi: 1
#   someth truli: 1
#   realli miracl: 1
#   john krasinski: 1
#   motiv viciou: 1
#   karen gillan pom klementieff: 1
#   linda cardellini judi: 1
#   unfortun agenda push: 1
#   honestli nwh best movi: 1
#   nice goodby beauti: 1
#   peter miser: 1
#   mayb someon: 1
#   issu bitth: 1
#   groot accompani: 1
#   amazingfunni: 1
#   gamora groot: 1
#   realli truli horribl: 1
#   geniu kudo: 1
#   momentth: 1
#   pleaseth counterearth: 1
#   everi advanc: 1
#   el mcu come: 1
#   mcu garbag: 1
#   drama silli funni heartfelt: 1
#   repris: 1
#   stakar ravag: 1
#   crossov thor: 1
#   appar entir: 1
#   sparkl shine: 1
#   supris time: 1
#   happi peter: 1
#   relat rememb: 1
#   everi movi mani movi: 1
#   bill murray fail horribl: 1
#   disney plu: 1
#   karen gillan realli: 1
#   peter quill bradley: 1
#   cooper: 1
#   thrill captiv: 1
#   abil: 1
#   narr everi: 1
#   hilari heartfelt: 1
#   funni seriousperson: 1
#   howev guardian: 1
#   captiv extraordinari film: 1
#   villain motiv: 1
#   storylin: 1
#   includ contemporari: 1
#   silli putti: 1
#   sorri kang: 1
#   kidsmani mani far mani: 1
#   everi minut joke: 1
#   uniqu beauti: 1
#   rapidli mechan: 1
#   rocket quill: 1
#   aveng focu: 1
#   jame gunn tall task outdo: 1
#   miracul recoveri: 1
#   beauti dark: 1
#   gamora new gamora everyon el kind fall: 1
#   includ remov: 1
#   cri cri: 1
#   goodby fan guardian: 1
#   weirdo: 1
#   nebula superb: 1
#   horribl movi: 1
#   dave bautista rest: 1
#   journey discoveri: 1
#   gunn idea: 1
#   essenti equival aveng endgam: 1
#   offi wish: 1
#   peter mother second: 1
#   gamei liter: 1
#   michael rooker: 1
#   cameo worth: 1
#   howev dialogu: 1
#   someth treasur: 1
#   jame gunn want everi guardian movi: 1
#   aveng split: 1
#   donei: 1
#   gog follow: 1
#   howev felt: 1
#   beth: 1
#   silli plotlin movi attempt: 1
#   questionablegog: 1
#   disguis compass: 1
#   mcu derang: 1
#   motiv: 1
#   titl sam raimi spiderman: 1
#   big aveng assembl: 1
#   jso: 1
#   filmmak motiv inspir vision: 1
#   chang pace: 1
#   excessivegamorrah realli: 1
#   aveng decent: 1
#   absolut bang: 1
#   awesom battl: 1
#   issu thor: 1
#   strang thor: 1
#   thano kang: 1
#   gunn realli skill director movi: 1
#   shang chi realli: 1
#   peter drax nebula play chri pratt dave: 1
#   peter desper: 1
#   bautista brought: 1
#   lastli gillan play: 1
#   sinc gamora: 1
#   manti peter: 1
#   gunn maria baklava: 1
#   gamora peter quill: 1
#   themw cri: 1
#   perfectli merg togeth realli: 1
#   knight nolan: 1
#   allud trailer: 1
#   compar ego ronan: 1
#   complexth high: 1
#   rocket racoon becom: 1
#   hilari: 1
#   cri slacker: 1
#   earthl alter ego peter quill trap face: 1
#   dave bautista protest: 1
#   kraglin struggl: 1
#   gunn associ: 1
#   mcuso peter quill utter immort: 1
#   tim curri dr frankenfurt mad: 1
#   atmosphereth perform: 1
#   dave bautista bradley cooper vin: 1
#   depth storyguardian: 1
#   sourc materi film: 1
#   gunn tri cram: 1
#   differ plotlin: 1
#   assert gamora: 1
#   gamora kinda: 1
#   fulli bake: 1
#   appar tri cram: 1
#   rocket gamora peter lylla: 1
#   pan howev: 1
#   movieth movi honestli: 1
#   associ: 1
#   peter returngamora great: 1
#   gunn surround: 1
#   cri beauti stori mani: 1
#   quill nebula one joke: 1
#   jeff: 1
#   firelord superboy: 1
#   chang bipolar: 1
#   mistook loud: 1
#   salvag wreckag: 1
#   obnoxi yell: 1
#   iffi plotlin: 1
#   plotlin: 1
#   everi length possibl save: 1
#   gunn half expect: 1
#   john cena: 1
#   chang exampl evolutionari: 1
#   cruel horribl everyon anyon: 1
#   trimmer tightli: 1
#   nebula karen gillan final: 1
#   loveth film: 1
#   kidshav: 1
#   guardianjam gunn: 1
#   accent gamora: 1
#   fantasi aveng seri thor: 1
#   cuddl coupl hour: 1
#   quill extrem: 1
#   chang anyth end spend: 1
#   chao sudden: 1
#   everi realli: 1
#   depriv horribl: 1
#   gunn thatwhil: 1
#   justifi goalswith: 1
#   manti nebula: 1
#   palett beauti: 1
#   figur: 1
#   everi second either: 1
#   constantli yell: 1
#   appar reason: 1
#   toneth film end: 1
#   gunn skill filmmak: 1
#   cooper chukwudi: 1
#   knowdo: 1
#   awesom whacki cool: 1
#   yondu: 1
#   beauti put togeth bullsit: 1
#   dave bautista phenomen: 1
#   mayb one: 1
#   gunn spin: 1
#   emoton: 1
#   dr strang thor: 1
#   everi immens: 1
#   peter quill nebula: 1
#   grammar vocabulari english: 1
#   relat howev: 1
#   someth realli: 1
#   yada yada yada originalth villain rocket: 1
#   headon movi realli: 1
#   dedic amus: 1
#   amus delight: 1
#   zoe saldaña gamora: 1
#   peter starlord quill play: 1
#   includ jokegunn: 1
#   dave bautista pom klementieff bradley: 1
#   cooper vin: 1
#   gunn repris: 1
#   film chukwudi iwuji: 1
#   howev peopl realli moviein: 1
#   everyth el: 1
#   howev bizarr: 1
#   chri pratt peter: 1
#   quill dave batista: 1
#   everyth mcu ridicul: 1
#   everi month: 1
#   karen gilan: 1
#   gamora dave bautista drax karen gillan nebula bradley cooper: 1
#   spectacleth visual: 1
#   reson fill surpris: 1
#   gamora long: 1
#   realli enjoy movi jame gunn: 1
#   peter quil guardian: 1
#   goodby motley: 1
#   racoon bradley: 1
#   karen gillan assassin zoe saldana: 1
#   silli intrigu includ quill: 1
#   complimentari waysur: 1
#   gravita aveng: 1
#   potenti homag: 1
#   ben affleck: 1
#   scenei know: 1
#   chao barbenheim: 1
#   rise heartfelt: 1
#   refer perfectw grew: 1
#   dougla: 1
#   introduc chang: 1
#   movi elegantli: 1
#   saldanakaren gillianbradley: 1
#   koppani dave: 1
#   peter star: 1
#   lordquil pratt: 1
#   appar caus: 1
#   peter quillstarlord howev tragedi: 1
#   comaso peter quill starlord buddi: 1
#   experi rang: 1
#   aboutc like: 1
#   angel imprison child: 1
#   gunn triedol gunn: 1
#   everi min: 1
#   happi slightli: 1
#   diam maecena ligula: 1
#   john wick receiv ton: 1
#   mayb intent: 1
#   theme chang: 1
#   relat otherw: 1
#   horribl realiti: 1
#   imag gamora: 1
#   karen gillan pom: 1
#   cooper vin diesel servic: 1
#   peter quillstarlord chri: 1
#   heroesadmittedli apprehens: 1
#   qualiti someon: 1
#   journey certainli: 1
#   lose gamora: 1
#   peter quill matur: 1
#   aveng infin: 1
#   gamora natur: 1
#   youv: 1
#   vari qualiti: 1
#   gotten lazi tire: 1
#   nothingsometim: 1
#   everi creator: 1
#   jame gunn manag combin: 1
#   seri mustwatch fan film: 1
#   qualiti someth: 1
#   gunn mindat time: 1
#   realiti coupl: 1
#   comfortingif manag: 1
#   squirrel tree: 1
#   insert everi scene repetit: 1
#   gunn person: 1
#   goof: 1
#   dave bautista save: 1
#   dave chri pratt: 1
#   howev: 1
#   cri absolut: 1
#   horribl everi: 1
#   howard duck guardian: 1
#   strang anyon: 1
#   terrif realli nice chang: 1
#   realli enjoy movi: 1
#   funni dialoguesth: 1
#   messi enjoyableth: 1
#   awesom alwaysso good movi: 1
#   compar mcu film: 1
#   furiou chukwudi iwuji: 1
#   klementieff awesom dialogu: 1
#   cheesi moment: 1
#   cooper bad: 1
#   joe pesci: 1
#   dave bautista consist: 1
#   peter utter disregard: 1
#   gunn uniqu: 1
#   sorri lazytrilog: 1
#   sometim conveyor belt movi: 1
#   unfortun notth: 1
#   adam warlock sinc tea: 1
#   gunn felt wholesom brought lot: 1
#   liter god: 1
#   kang dynasti: 1
#   awesom superhero: 1
#   potenti: 1
#   multipl civilizationsth: 1
#   someth bizarr: 1
#   ravag sooner: 1
#   liter knowher: 1
#   kettl: 1
#   humour quill: 1
#   know gamora zoe saldana aliv: 1
#   starlord chri pratt: 1
#   dave bautista nebula karen gillan groot: 1
#   nonaveng: 1
#   endgam kudo: 1
#   chang much sinc first: 1
#   starlord karen gillan: 1
#   nebula well: 1
#   peter quill lead ragtag: 1
#   extrem manipul cage: 1
#   jame gunn deliv realli: 1
#   stuck tri: 1
#   mostli: 1
#   slapstick humour: 1
#   tragedi rocket backstori: 1
#   peter quill gamora: 1
#   seventitl brazil: 1
#   gang peter quill: 1
#   peter moment trilog: 1
#   quill nebula: 1
#   accompani activ trademark guardiansc skip: 1
#   honestli hardli: 1
#   wholli justifi: 1
#   definit exaggerationjamesgunn: 1
#   frickinn: 1
#   nebula karengillan final chang: 1
#   gamora zoesaldanacom: 1
#   kraglin thejudgegunn: 1
#   yondu udonta: 1
#   michael rookerthough yondu: 1
#   lightli: 1
#   originalityh: 1
#   someon el hous: 1
#   flashi visual possibl: 1
#   downhil thor: 1
#   nutshel: 1
#   chri pratt zoe: 1
#   dave bautista karen gillan pom kementieff vin diesel bradley cooper: 1
#   kevin bacona: 1
#   excellentth: 1
#   sarah mclachlan: 1
#   jerk halfway: 1
#   gamora littl: 1
#   moviesso: 1
#   gog vol consid final: 1
#   movi seriesth humor: 1
#   forgetableth: 1
#   peter bicker: 1
#   know smart comic know: 1
#   rocket mayb: 1
#   idiosyncrat moment: 1
#   reconnect gamora: 1
#   doubt gunn guardiansth: 1
#   shine closur: 1
#   rocket irrit: 1
#   motiv gotg: 1
#   peter skylord tri make gamora: 1
#   disintegr peter: 1
#   peter quill scene: 1
#   everi angl: 1
#   everi charactereveri: 1
#   rocket raccoonif: 1
#   peter convers gamora realli heartfelt young: 1
#   jub jub: 1
#   obviou chang: 1
#   chang contrari peopl: 1
#   realli realli: 1
#   nostalg howev: 1
#   behav melancholi: 1
#   repeatedli assault: 1
#   whistl: 1
#   malcolm: 1
#   brilliantli chukwudi iwuji: 1
#   greasi meatbal: 1
#   battl: 1
#   fulli showcas guardian distinct abil fluent combo: 1
#   gunn peculiarli: 1
#   sky gene gog: 1
#   peter develop: 1
#   sen godli: 1
#   assault howev defeat: 1
#   derang motiv: 1
#   gunn creativ indefatig: 1
#   chord comic fan: 1
#   michael rooker yondu: 1
#   dr moreauat: 1
#   includ peter: 1
#   tricki chang: 1
#   kind materi: 1
#   chukudi iwuji: 1
#   gillan pom klementieff: 1
#   gunn helm mayb: 1
#   wacki strang: 1
#   happen gamora guardian end: 1
#   realli enjoy film: 1
#   david bowi: 1
#   pat benatar: 1
#   movi beauti: 1
#   gunn henri: 1
#   dave bautista karen gillan rest: 1
#   vfx beauti: 1
#   chao guardian: 1
#   gunn kraglin: 1
#   minut mayb: 1
#   evenregard flaw flaw: 1
#   kang multivers: 1
#   everyth el excel: 1
#   journey laughter: 1
#   gunn expertli: 1
#   leav eagerli: 1
#   conclus howev: 1
#   xmaa: 1
#   thou mayb: 1
#   groov dave bautista: 1
#   motiv everyon come: 1
#   jame gunn beauti laugh: 1
#   mosaic emot: 1
#   chang sourc materi: 1
#   superman legaci: 1
#   mcu gunn brought: 1
#   nebula kraglin: 1
#   cri mani time: 1
#   kidsyou cri: 1
#   realli fond mcu: 1
#   zoe karen bautista onon: 1
#   howev pace: 1
#   littl missplac sometim: 1
#   quill final: 1
#   beauti heartwarm: 1
#   sceneth abil: 1
#   realli guardian: 1
#   howev gang thrust back: 1
#   aveng seri film: 1
#   gofg: 1
#   disjoint narr: 1
#   juggl numer: 1
#   selv: 1
#   necessari dramat tension: 1
#   rang breathtakingli beauti distractingli artifici: 1
#   deliv awhil: 1
#   kubrick long: 1
#   relat everi: 1
#   everi major: 1
#   tragedi: 1
#   societi stuff: 1
#   somei: 1
#   poop gamora: 1
#   chao buckl gunn: 1
#   compar previou one: 1
#   kang least thano: 1
#   gamora quill handl: 1
#   peter quill nebula swole: 1
#   fatherjohn murphi beauti: 1
#   angenieux oprimo: 1
#   ravag kraglin: 1
#   lotth battl: 1
#   jimmi gunn everyon stay: 1
#   movi honestli glad: 1
#   gunn genuin: 1
#   gamora liter: 1
#   everyth el genuin: 1
#   pan slip: 1
#   mayb littl: 1
#   mayb matur: 1
#   focu qualiti: 1
#   sam raimi movi: 1
#   movieth technic: 1
#   nitpick neg: 1
#   kinda wish hadntoth felt: 1
#   kinda horrif: 1
#   relat awesom: 1
#   awesom abil: 1
#   manti honestli: 1
#   kudo chukwudi iwuji: 1
#   movi messi: 1
#   someon mani: 1
#   intro: 1
#   radioheadchri pratt fantast: 1
#   rocket lifei: 1
#   defiantli: 1
#   kudo tyler: 1
#   interplanetari: 1
#   mayb gunn realli: 1
#   everi actor: 1
#   horribl watch: 1
#   peter groot: 1
#   joe biden: 1
#   everi type genr: 1
#   stark chang: 1
#   associ mcu guardian franchis: 1
#   realli manag: 1
#   gunn geniu: 1
#   everi manner: 1
#   insert multipl: 1
#   closur gamora: 1
#   drax mantisth: 1
#   nebula karen gillen reach gamora zoe saldana: 1
#   helpy cri: 1
#   accept gamora: 1
#   servic abil: 1
#   silli part: 1
#   everi gg scene: 1
#   everi minut hilari movi: 1
#   realiti mani: 1
#   thatth computerg imageri: 1
#   howev mani: 1
#   gunn cater: 1
#   peter quill starlord realli abandon: 1
#   heavilyfrom sam raimi spiderman aveng endgam mani: 1
#   happen aveng age: 1
#   uncl ben: 1
#   gunn everyon: 1
#   beforeyeajam gunn: 1
#   peter come: 1
#   ya cri: 1
#   peter one: 1
#   beauti goodby: 1
#   mcujam gunn: 1
#   peter quill starlord stood: 1
#   lightyet time: 1
#   calam: 1
#   peter weigh: 1
#   intens scari visual stun: 1
#   aveng film cours: 1
#   racoon mostli: 1
#   quickli: 1
#   memor honestli littl: 1
#   stuff aveng: 1
#   spinoff bautista drax: 1
#   quill allegedli funni line: 1
#   deliveri bautista: 1
#   sarah alami: 1
#   forget lee: 1
#   nebula play: 1
#   wan na: 1
#   pom klementiff: 1
#   specul lead puzzl: 1
#   gunn comment: 1
#   everyon yell: 1
#   rip gamora peter kill: 1
#   societi experi other crush anyon: 1
#   aveng filmsi: 1
#   everi young: 1
#   margaret: 1
#   dysney ja complet: 1
#   reanim reaon: 1
#   dave bautista drax sceneri: 1
#   everi thread: 1
#   sorri hell: 1
#   ymmv st gotg one: 1
#   mayb scoobydoo: 1
#   everi gotg: 1
#   revit dcuaa: 1
#   howev film messi: 1
#   distanc polit: 1
#   dr strang movi guardian: 1
#   mayb simpli: 1
#   cronenberg inspir: 1
#   nowgunn realli: 1
#   brad pitt chri pratt: 1
#   deliv someth: 1
#   everi mcu movi follow: 1
#   film gunn: 1
#   maudlin: 1
#   jame gunn nail againcomplet emot: 1
#   everi emotionu: 1
#   experi: 1
#   kang scari: 1
#   gunn entir: 1
#   averag write: 1
#   gunn gotten: 1
#   tug string: 1
#   chang yearsthi film: 1
#   whyjam gunn: 1
#   tromeo juliet: 1
#   quarter bin starlord: 1
#   divid usa: 1
#   sort gener: 1
#   stan mayb: 1
#   chang interplanetari: 1
#   everi everi year: 1
#   jim valentino creat: 1
#   annihil conquest: 1
#   aveng film comed liftso gunn: 1
#   jedi constantli: 1
#   challeng: 1
#   push emotionsa: 1
#   rememb gamora zoe saldana: 1
#   nebula karen gillan make: 1
#   dave bautista alway: 1
#   gamora starlord yondu: 1
#   nebula forthcom: 1
#   michael rosenbaum mainfram: 1
#   howard duck seth green broker christoph: 1
#   rhett miller: 1
#   rocket throwaway: 1
#   legendari starlord: 1
#   everi jame: 1
#   john: 1
#   peter rocket groot: 1
#   nonethelessdespit: 1
#   chang natur cours: 1
#   thano gamora gotg ego quill high: 1
#   cooki: 1
#   aveng felt: 1
#   chemistri klementieff: 1
#   happi bautista: 1
#   gunn juggl: 1
#   extrem cheesi: 1
#   everyon constantli: 1
#   selv multifacet: 1
#   elicit laughter: 1
#   showcas trademark: 1
#   gunn magnific job: 1
#   sparkl captiv: 1
#   strang multivers mad realli: 1
#   meek: 1
#   par gunn fail one: 1
#   everi mcu fan: 1
#   rian johnson: 1
#   expec gunn subvert emot: 1
#   gunn undoubtedli: 1
#   art howev: 1
#   goodby seri: 1
#   mostli sendoff piec: 1
#   storylin gunn remark storytel: 1
#   masteri: 1
#   icki gunn quickli: 1
#   appar leav: 1
#   sourc materi: 1
#   confus honestli: 1
#   dramat heft sinc: 1
#   realli didntwhil guardian: 1
#   chri pratt bradley: 1
#   cooper karen gillan dave bautista pom klementieff vin: 1
#   rocket badli injur: 1
#   motiv suitabl: 1
#   climat chang: 1
#   steve roger: 1
#   everi crimin: 1
#   summar struggl: 1
#   everi charact wrap: 1
#   peter place: 1
#   happi wrap: 1
#   issu quill: 1
#   pace gunn: 1
#   basi gotg moviea: 1
#   peter heavi movi: 1
#   peter ongo: 1
#   specif gamora: 1
#   chang cours: 1
#   quantum messi predict: 1
#   awesom hilari: 1
#   aveng endgam: 1
#   someth dave bautista drax: 1
#   miseri chri pratt: 1
#   appar know: 1
#   chri pratt star: 1
#   vin deisel: 1
#   debat qualiti quantiti: 1
#   critiqu movi: 1
#   compar other seri: 1
#   thano ultron: 1
#   everi levellastli: 1
#   otheri thoroughli enjoy caveat: 1
#   karen gillan rate deserv: 1
#   labmeanwhil peter quill chri pratt guardian: 1
#   gunn silli banter: 1
#   peter watch: 1
#   michael keaton: 1
#   activ: 1
#   dx experi worth: 1
#   saldaña vin diesel dave bautista: 1
#   karen gillan name: 1
#   nitpicki comic book: 1
#   impressedchukwudi iwuji: 1
#   botch kang antman: 1
#   peter clone: 1
#   potenti surpass: 1
#   veng god: 1
#   depress gamora zoe saldana: 1
#   trap peter: 1
#   karen gillan gamora: 1
#   elizabeth debecki: 1
#   everi jokethi movi: 1
#   soundtrack besid: 1
#   nebula awesom: 1
#   motiv par thano: 1
#   chang happi departur: 1
#   conveni: 1
#   nightmar littl: 1
#   everyon piec cake: 1
#   goodby guardian howev guardian: 1
#   david ayer: 1
#   conveni peter onetim: 1
#   geneexperi kid: 1
#   peter rescu: 1
#   peter halfsibl: 1
#   compar recent slog marvel movi: 1
#   delight watchjam: 1
#   alli: 1
#   masteri whistl: 1
#   poultermidsommar miller: 1
#   minutesi realli: 1
#   mayb funni: 1
#   gotg supris: 1
#   whole gamora: 1
#   felt gamora: 1
#   dirti: 1
#   realli badli quill realli: 1
#   kg heavier last movi: 1
#   gaurdian heartwarm: 1
#   realli enjoy charact: 1
#   howev aslo: 1
#   gamora memori: 1
#   talik someth: 1
#   togeth flashi: 1
#   triedandtru method: 1
#   multipl levelsin: 1
#   laughter tearjerk: 1
#   journey explor dark: 1
#   correctli littl: 1
#   cinema de lux: 1
#   narr delv: 1
#   rang emot: 1
#   jame gunn guardian galaxi: 1
#   starlord assembl guardian: 1
#   cooper dave bautista zoe: 1
#   karen gillan chukwudi: 1
#   rehir gunn: 1
#   lover absolut: 1
#   scene peter: 1
#   includ chri pratt zoe saldana vin diesel bradley cooper dave bautista: 1
#   day howev: 1
#   gunn provid: 1
#   movi aveng: 1
#   el heartfelt scene: 1
#   silli joke: 1
#   silli stuff: 1
#   awesom howard duck: 1
#   fleshi monstrou: 1
#   lose gamora guardian: 1
#   experi mad: 1
#   fun peter: 1
#   peter nebula: 1
#   gunn realli great job: 1
#   theater howev: 1
#   nebula disjoint narr: 1
#   narr chao: 1
#   tug heartstr: 1
#   gunn visionari direct: 1
#   shine kevin: 1
#   hahaha: 1
#   gunn plea: 1
#   kinda exactli: 1
#   cooper fine honestli felt: 1
#   kinda: 1
#   mostli awesom: 1
#   rocket battl: 1
#   iwuji motiv want chang: 1
#   nomin sinc: 1
#   mcu string: 1
#   sinc aveng saga: 1
#   spectacl togeth: 1
#   himwhil rocket: 1
#   rocket howev: 1
#   variant gamora: 1
#   mani jokesa nebula: 1
#   narr howev gunn: 1
#   chang sourc materi core: 1
#   themextrem: 1
#   cri happi: 1
#   chemistri nebula: 1
#   happi sky despit dark heavi theme: 1
#   realli goodth narr: 1
#   howev unfortun: 1
#   funni heartwarm: 1
#   specul someon: 1
#   peter quill starlord: 1
#   plenti enjoy tad overlong: 1
#   gunn vision: 1
#   big zit: 1
#   strang type familyi: 1
#   dave baustista certainli: 1
#   everi spectacular: 1
#   bubbl nebula vin dieself: 1
#   dave bautistadun: 1
#   blanc mysteri: 1
#   coopernightmar alli: 1
#   klementieffthunderforc mantisdaniela: 1
#   gunnguardian galaxi: 1
#   kraglin linda cardellinihawkey: 1
#   chukwudi iwujijohn: 1
#   john murphyarmor: 1
#   heartno: 1
#   dog karrigan: 1
#   wit miracl imposs: 1
#   qualiti absolut: 1
#   gunn compani: 1
#   beauti job wrap: 1
#   reson narr: 1
#   closur gomorrah: 1
#   knowhereth guardian: 1
#   essenti conclud: 1
#   gunn slither: 1
#   dave bautista nebula karen gillan manti pom: 1
#   elizabeth debicki rocket: 1
#   overpow forc: 1
#   gamora zoe saldana join: 1
#   ravag help guardian infiltr orgocorp: 1
#   depart counterearth follow: 1
#   gamora rocket peter quill groot nebula: 1
#   groot leap: 1
#   gamora arriv: 1
#   rescu nebula: 1
#   flatlin neardeath experi: 1
#   gunn james: 1
#   adam chang: 1
#   quill leav guardian pas roll: 1
#   gregg henri: 1
#   journey selfdiscoveri abilisk gamora reunit ravag nebula: 1
#   rocket groot: 1
#   baker: 1
#   karen abercrombi: 1
#   michael rooker yondu udonta judi: 1
#   bautista gillan rest: 1
#   battl highspe: 1
#   amus moment: 1
#   awesom song: 1
#   ura linda cardellini: 1
#   eric grade: 1
#   gunn drama: 1
#   societi includ: 1
#   modif: 1
#   peter quillnebula: 1
#   gravita: 1
#   kang throat: 1
#   david benatar: 1
#   rocket gamora: 1
#   perfectli: 1
#   aveng miss: 1
#   guardian strang: 1
#   surgeri mechan: 1
#   evok rang: 1
#   gog tri copi: 1
#   audienceim realli proud: 1
#   usyouv combin funni: 1
#   everi sceneeveri: 1
#   goodby plea wish: 1
#   describejam gunn: 1
#   peter togeth: 1
#   mari poppin: 1
#   potenti one: 1
#   manag extrem mcu movi: 1
#   gallon emot: 1
#   unfortun gotten: 1
#   relat qualiti: 1
#   whine gamora: 1
#   cameo nathan: 1
#   everi monthw: 1
#   thou howev: 1
#   teef floor: 1
#   everi rate: 1
#   peter groot nebula: 1
#   song varieti: 1
#   realiti faketh: 1
#   movi gaug one: 1
#   arc gamora: 1
#   anyth: 1
#   toeschang: 1
#   level gunn: 1
#   shi belong: 1
#   everi flaw: 1
#   mayb final: 1
#   lloyd kaufman: 1
#   howard duck mani: 1
#   quot someon: 1
#   lordpet quill chri pratt: 1
#   dace bautista manti pom: 1
#   david bautista sweet: 1
#   plu adult: 1
#   kang dynastycring lot: 1
#   death gamora deal possibl: 1
#   realli welli: 1
#   dave bautista definit: 1
#   liter doubt: 1
#   juggernaut aveng endgam: 1
#   potenti harbour: 1
#   closur humanli: 1
#   everyth theoret: 1
#   matur peter gamora: 1
#   challeng everi: 1
#   journey satisfyingli: 1
#   analys inspir: 1
#   rebelli: 1
#   grootth handl peter gamoraeveryon: 1
#   everi next: 1
#   flawlesslyeveri singl: 1
#   everi genr: 1
#   gunn liter: 1
#   stuck mindth: 1
#   lyric ab: 1
#   gunn creat beauti filmwhen watch movi sometim: 1
#   cri howev: 1
#   guardian galaxi gamora: 1
#   attitud gamora peter: 1
#   definit gamora: 1
#   peter act: 1
#   karen gillan captur nebula: 1
#   auteur jame gunn make: 1
#   pristin detail: 1
#   onelin gunn: 1
#   figur quill: 1
#   gamora longer recuper one: 1
#   alert fron begin unto: 1
#   chang grootth: 1
#   quill doesth stori: 1
#   gamora peter: 1
#   archetyp: 1
#   battl honestli: 1
#   couldv mcu save: 1
#   hardi: 1
#   cater: 1
#   gamora everyth: 1
#   everi iter: 1
#   funni part: 1
#   gofg jame: 1
#   peter quillstarlordchri pratt: 1
#   bautista grootvin diesel nebulakaren: 1
#   saldana peter rest guardian: 1
#   peter quillstarlord bradley: 1
#   manti dave bautista hyster: 1
#   nebula vin diesel: 1
#   awesom adam: 1
#   sean gunn great: 1
# Entity Type: DATE => Total: 203
#   year: 41
#   today: 18
#   last year: 14
#   day: 11
#   recent year: 9
#   year ago: 8
#   six year: 5
#   winter: 4
#   week: 4
#   yesterday: 4
#   past year: 3
#   sunday: 3
#   month: 3
#   presentday: 2
#   nowaday: 2
#   five year old: 2
#   two year: 2
#   weekend: 2
#   summer: 2
#   earli day: 2
#   june: 2
#   year later: 2
#   one day: 2
#   last day: 1
#   like year ago: 1
#   next quarterli: 1
#   year old: 1
#   endingnowaday: 1
#   destructionth: 1
#   hour day: 1
#   month sinc: 1
#   im year old: 1
#   heist first half: 1
#   april: 1
#   weak year: 1
#   first half despit: 1
#   week hole g week end: 1
#   last season: 1
#   nearli year: 1
#   supervillainth: 1
#   day later: 1
#   quit year: 1
#   missionth: 1
#   first dad: 1
#   year sinc: 1
#   sinc first: 1
#   allov past year: 1
#   almost nine year: 1
#   film year: 1
#   last eight year: 1
#   nonspidey: 1
#   earlier year: 1
#   last quarter: 1
#   spring: 1
#   thursday: 1
#   final year: 1
#   look week: 1
#   first half act: 1
#   mid late: 1
#   year l: 1
#   nine year ago: 1
#   funth: 1
#   premier day: 1
#   ten year: 1
#   fifteen year: 1
#   ten year ago: 1
#   onth: 1
#   right film year: 1
#   four day later: 1
#   experi anim order day end: 1
#   month ago: 1
#   million year: 1
#   first thirti year: 1
#   season: 1
#   one good day: 1
#   openth: 1
#   five year ago: 1
#   last week: 1
#   prior year: 1
# Entity Type: GPE => Total: 336
#   gunn: 58
#   mayb: 18
#   mostli: 15
#   adventur: 15
#   saldana: 14
#   storylin: 13
#   kraglin: 13
#   believ: 13
#   thrill: 12
#   quantumania: 11
#   qualiti: 8
#   america: 7
#   clunki: 6
#   measur: 6
#   figur: 5
#   quantiti: 5
#   importantli: 4
#   sappi: 3
#   someth el: 3
#   departur: 3
#   new zealand: 2
#   quantamania: 2
#   nativ: 2
#   dynam: 2
#   fulli: 2
#   wanda: 2
#   new york: 2
#   showcas: 2
#   downhil: 2
#   camaraderi: 2
#   truli: 2
#   hardli: 2
#   obnoxi: 2
#   nostalg: 2
#   klementieff: 2
#   someth el bloat: 1
#   meaningse: 1
#   netflix: 1
#   funnya: 1
#   anyon el happi movi: 1
#   marvellik: 1
#   everyon el: 1
#   quantummania: 1
#   hollywood: 1
#   entir storylin fill repetit: 1
#   loki: 1
#   halleng: 1
#   reviv: 1
#   moreit: 1
#   quizzic: 1
#   indiana: 1
#   villan: 1
#   cri: 1
#   saigon: 1
#   reptilian: 1
#   surviv: 1
#   tipsi: 1
#   villin: 1
#   watchsur: 1
#   el: 1
#   tokyo: 1
#   new gamora: 1
#   rocket racoon: 1
#   redemptionth: 1
#   happi: 1
#   retrac: 1
#   quietli: 1
#   betteri: 1
#   revit: 1
#   uk: 1
#   spectacl: 1
#   gunn reviv: 1
#   megalomania: 1
#   headlin: 1
#   adventur explos: 1
#   unsur: 1
#   punchlin: 1
#   vaniti: 1
#   wakanda: 1
#   slightli: 1
#   endbravo: 1
#   storyim: 1
#   immin: 1
#   bett: 1
#   likeim: 1
#   correctli: 1
#   foundon: 1
#   brightli: 1
#   hundr: 1
#   el entertain anymor space: 1
#   continueand: 1
#   missouri: 1
#   adventur base: 1
#   mcuundoubtedli: 1
#   melancholyi: 1
#   commendedi: 1
#   nostolg: 1
#   teh villan: 1
#   meme: 1
#   anythingseri: 1
#   quill dislik: 1
#   believ jame: 1
#   el nio sin: 1
#   kinda: 1
#   itsur: 1
#   delayguardian: 1
#   kinda dark marvel: 1
#   daniela: 1
#   repeatedli: 1
# Entity Type: NORP => Total: 483
#   seri: 158
#   cri: 87
#   hilari: 35
#   experi: 29
#   surpris: 24
#   everi: 22
#   sean: 16
#   imageri: 7
#   russian: 7
#   american: 6
#   camaraderi: 6
#   undeni: 5
#   soviet: 4
#   expans: 4
#   trilogyguardian: 3
#   english: 3
#   christian: 3
#   infus: 3
#   simultan: 3
#   polish: 3
#   surgeri: 2
#   conveni: 2
#   german: 2
#   unpolish: 2
#   guardiansguardian: 2
#   gardian: 2
#   januari: 2
#   heartguardian: 1
#   generationguardian: 1
#   secondari: 1
#   wowguardian: 1
#   subseri: 1
#   kitsh: 1
#   freeli: 1
#   planetari: 1
#   gruesom: 1
#   visionari: 1
#   twist entertain funni: 1
#   awesom: 1
#   asian: 1
#   european: 1
#   galaxyseri: 1
#   closureguardian: 1
#   trex: 1
#   movieguardian: 1
#   hima: 1
#   starsguardian: 1
#   ingeni: 1
#   abhorr: 1
#   journeyguardian: 1
#   childreni: 1
#   bulgarian: 1
#   korean: 1
#   slipperi: 1
#   monopolis: 1
#   moroccan: 1
#   plu dropdead gorgeou: 1
#   warsargu: 1
#   sciencevisu: 1
#   withguardian: 1
#   unfoldth: 1
#   wasteeveri: 1
#   astound: 1
#   teef asim: 1
#   repris: 1
#   austrian: 1
#   dguardian: 1
#   greek: 1
# Entity Type: TIME => Total: 75
#   two half hour: 17
#   hour: 15
#   half hour: 9
#   two hour: 5
#   night: 4
#   first hour: 2
#   last night: 2
#   last hour: 1
#   thank hour hour: 1
#   anoth hour: 1
#   opinionth first hour: 1
#   first long hour: 1
#   â½ hour: 1
#   first half hour: 1
#   context hour: 1
#   btw least one hour: 1
#   one afternoon: 1
#   hour second half: 1
#   togeth: 1
#   half hour around half hour: 1
#   half hour ago: 1
#   third time sever hour ago: 1
#   almost exactli hour: 1
#   tonight: 1
#   afternoon: 1
#   almost hour: 1
#   twoandahalf hour: 1
#   mostli: 1
# Entity Type: EVENT => Total: 3
#   storylin perfectli: 1
#   believ everi moment: 1
#   mysteri: 1
# Entity Type: PRODUCT => Total: 42
#   everi: 5
#   everi charact: 3
#   everi member: 1
#   everi one: 1
#   mesmeris moment: 1
#   darker moment: 1
#   everi moment: 1
#   everi singl: 1
#   funni moment: 1
#   narr: 1
#   everi charact kooki: 1
#   evulutionari one: 1
#   silli charact: 1
#   everi charact loo: 1
#   gunn direct one: 1
#   worri new: 1
#   genr: 1
#   worri one: 1
#   repris: 1
#   sean: 1
#   buffooneri: 1
#   mcu guardian: 1
#   howev antman: 1
#   everi charact arc: 1
#   experi howev: 1
#   worri surviv: 1
#   seri: 1
#   guardian galaxyth third volum: 1
#   kinda: 1
#   plu one: 1
#   everi movi: 1
#   summari guardian: 1
#   sky beauti cri hard dog: 1
#   awesom hero: 1
#   achievementin conclus guardian: 1
#   undoubtedli: 1
# Entity Type: FAC => Total: 20
#   gunn couldv: 2
#   depict happi heterosexu relationship like: 1
#   gunn amazingli: 1
#   jame gunn produc uniqu brilliantli entertain trilog: 1
#   quantumania honestli kinda: 1
#   jame gunn perfectli: 1
#   mediocritiesth guardian: 1
#   gunn decid: 1
#   mayb g neb manag fine absenc: 1
#   chukwudi iwuji: 1
#   hour bittersweet: 1
#   gunn poetic geniu craft storytel astonish movi: 1
#   jame gunn best movi: 1
#   quantumania gunn guardian fail make bank: 1
#   gunn realli know betterit: 1
#   racoon racoon: 1
#   aveng end gameit: 1
#   gunn earmark viewer: 1
#   neededjam gunn nail: 1
# Entity Type: WORK_OF_ART => Total: 17
#   titl sword star: 1
#   swan song: 1
#   gunn truli: 1
#   gunn defend idea famili welcom: 1
#   gunn master direct: 1
#   repris role chri pratt zoe saldana: 1
#   yellingth movi messi: 1
#   fuell: 1
#   swan song marvel sinc: 1
#   chukwudi iwuji: 1
#   inevit arriv charm: 1
#   swan song lineup guardian: 1
#   experi twist bio organ planet: 1
#   gunn direct deserv particular: 1
#   swan song movi: 1
#   materi deliv well: 1
#   gunn direct storytel prowess: 1
# Entity Type: LOC => Total: 15
#   earth: 4
#   bensonhurst: 1
#   expertli choreograph: 1
#   cri happi: 1
#   occas movi: 1
#   seri sniffl: 1
#   overdon gunn: 1
#   charm kraglin: 1
#   impactth: 1
#   abus villain: 1
#   nova: 1
#   selectionth movi: 1
# Entity Type: LANGUAGE => Total: 1
#   tortur hour: 1
# Entity Type: LAW => Total: 2
#   gann: 1
#   chapter sinc: 1
# Entity Type: QUANTITY => Total: 3
#   one everi timelin: 1
#   one everi movieh join: 1
#   one mile: 1
# Entity Type: MONEY => Total: 1
#   billion dollar: 1

# %% [markdown]
# #**Comment**
# Make sure to submit the cleaned data CSV in the comment section - 10 points

# %% [markdown]
# https://drive.google.com/drive/u/1/folders/1IKO2k1pW--2ewtz0duqDDzLsgEbB8FLy

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
'''
The assignment is good yet challenging, I really enjoyed scraping different movies reviews into a dataset.
I found the 3rd question quite challenging, it took most of the time I spent on the whole assignment.
Time provided to complete the assignment was good but having both in class excercise and assignemnt
in the same week made it even more challenging to meet the deadlines.

'''
# Out:
# '\nThe assignment is good yet challenging, I really enjoyed scraping different movies reviews into a dataset.\nI found the 3rd question quite challenging, it took most of the time I spent on the whole assignment.\nTime provided to complete the assignment was good but having both in class excercise and assignemnt\nin the same week made it even more challenging to meet the deadlines.\n\n'
